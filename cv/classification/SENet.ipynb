# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
import torch.optim as optim
import matplotlib.pyplot as plt
from collections import OrderedDict
from torchsummary import summary

# %matplotlib inline

# check device
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print("We use " + DEVICE)
torch.cuda.empty_cache()
# Out:
# We use cuda

# %%
batch_size = 32
learning_rate  = 1e-2
momentum = 0.5
epochs = 100
patience = 7

# %%
train_db = datasets.CIFAR10('datasets/cifar10',
                            train=True,
                            download=True,
                            transform=transforms.Compose([
                                transforms.Resize([256, 256]),
                                transforms.RandomCrop(224),
                                transforms.RandomHorizontalFlip(),
                                transforms.RandomVerticalFlip(),
                                transforms.RandomRotation(15),
                                transforms.ToTensor(),                       # 数据类型转化
                                transforms.Normalize(
                                    (0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))  # 数据归一化处理
                            ]))

test_db = datasets.CIFAR10('datasets/cifar10',
                           train=False,
                           download=True,
                           transform=transforms.Compose([
                               transforms.Resize([256, 256]),
                               transforms.RandomCrop(224),
                               transforms.RandomHorizontalFlip(),
                               transforms.RandomVerticalFlip(),
                               transforms.RandomRotation(15),
                               transforms.ToTensor(),
                               transforms.Normalize(
                                   (0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
                           ]))

print('train:', len(train_db), 'test:', len(test_db))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# train: 50000 test: 10000

# %%
train_db, val_db = torch.utils.data.random_split(train_db, [40000, 10000])

print('train:', len(train_db), 'validation:', len(val_db))
# Out:
# train: 40000 validation: 10000

# %%
train_loader = torch.utils.data.DataLoader(
    train_db,
    batch_size=batch_size,
    drop_last=True,
    shuffle=True
)

val_loader = torch.utils.data.DataLoader(
    val_db,
    batch_size=batch_size,
    drop_last=True,
    shuffle=False
)

test_loader = torch.utils.data.DataLoader(
    test_db,
    batch_size=batch_size,
    drop_last=True,
    shuffle=False
)

# %%
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print            
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}\n')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...\n')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %%
class BasicConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, relu=True, **kwargs):
        super(BasicConv2d, self).__init__()
        self.relu = relu
        if self.relu:
            self.features = nn.Sequential(
                nn.Conv2d(in_channels=in_channels,
                          out_channels=out_channels, **kwargs),
                nn.BatchNorm2d(num_features=out_channels),
                nn.ReLU(inplace=True),
            )
        else:
            self.features = nn.Sequential(
                nn.Conv2d(in_channels=in_channels,
                          out_channels=out_channels, **kwargs),
                nn.BatchNorm2d(num_features=out_channels),
            )

    def forward(self, x):
        out = self.features(x)
        return out

# %%
class SEBlock(nn.Module):
    def __init__(self, in_channels, reduction=16):
        super(SEBlock, self).__init__()
        self.avgpool = nn.AdaptiveAvgPool2d(output_size=(1, 1))
        self.feature = nn.Sequential(
            nn.Linear(in_channels, in_channels // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(in_channels // reduction, in_channels, bias=False),
            nn.Sigmoid(),
        )

    def forward(self, x):
        out = self.avgpool(x)
        out = out.view(x.size(0), -1)
        out = self.feature(out)
        out = out.view(x.size(0), x.size(1), 1, 1)
        return x * out.expand_as(x)

# %%
class SEBasicBlock(nn.Module):
    expansion = 1
    def __init__(self, in_channels, out_channels, stride=1, downsample=None):
        super(SEBasicBlock, self).__init__()
        self.features = nn.Sequential(
            BasicConv2d(in_channels=in_channels, out_channels=out_channels,
                        relu=True, kernel_size=3, stride=stride, padding=1, bias=False),
            BasicConv2d(in_channels=out_channels, out_channels=out_channels,
                        relu=False, kernel_size=3, stride=1, padding=1, bias=False),
            SEBlock(in_channels=out_channels),

        )
        self.downsample = downsample
        self.stride = stride

    def forward(self, x):
        if self.downsample is None:
            residual = x
        else:
            residual = self.downsample(x)
        out = self.features(x)
        out += residual
        out = F.relu(out, inplace=True)

        return out

# %%
class SEBottleneck(nn.Module):
    expansion = 4
    def __init__(self, in_channels, out_channels, stride=1, downsample=None):
        super(SEBottleneck, self).__init__()
        self.features = nn.Sequential(
            BasicConv2d(in_channels=in_channels, out_channels=out_channels,
                        relu=False, kernel_size=1, stride=1, padding=0, bias=False),
            BasicConv2d(in_channels=out_channels, out_channels=out_channels,
                        relu=False, kernel_size=3, stride=stride, padding=1, bias=False),
            BasicConv2d(in_channels=out_channels, out_channels=out_channels *
                        self.expansion, relu=True, kernel_size=1, stride=1, padding=0, bias=False),
            SEBlock(in_channels=out_channels),
            
        )
        self.downsample = downsample
        self.stride = stride

    def forward(self, x):
        if self.downsample is None:
            residual = x
        else:
            residual = self.downsample(x)
        out = self.features(x)
        out += residual
        out = F.relu(out, inplace=True)

        return out

# %%
class SEResNet(nn.Module):
    def __init__(self, block, layers, num_classes=10):
        super(SEResNet, self).__init__()
        self.in_channels = 64
        self.features = nn.Sequential(
            BasicConv2d(in_channels=3, out_channels=64, relu=True,
                        kernel_size=7, stride=2, padding=3, bias=False),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
        )
        self.layer1 = self._make_layer(
            block=block, out_channels=64, num_blocks=layers[0], stride=1)
        self.layer2 = self._make_layer(
            block=block, out_channels=128, num_blocks=layers[1], stride=2)
        self.layer3 = self._make_layer(
            block=block, out_channels=256, num_blocks=layers[2], stride=2)
        self.layer4 = self._make_layer(
            block=block, out_channels=512, num_blocks=layers[3], stride=2)
        self.avgpool = nn.AvgPool2d(kernel_size=7)
        self.fc = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride=1):
        downsample = None
        if stride != 1 or self.in_channels != out_channels * block.expansion:
            downsample = BasicConv2d(in_channels=self.in_channels, out_channels=out_channels * block.expansion, relu=False,
                                     kernel_size=1, stride=stride, bias=False)
        layers = []
        layers.append(block(in_channels=self.in_channels,
                            out_channels=out_channels, stride=stride, downsample=downsample))
        self.in_channels = out_channels * block.expansion
        for i in range(1, num_blocks):
            layers.append(block(in_channels=self.in_channels,
                                out_channels=out_channels))

        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.features(x)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out

# %%
def SEresnet18(**kwargs):
    model = SEResNet(SEBasicBlock, [2, 2, 2, 2], **kwargs)
    return model


def SEresnet34(**kwargs):
    model = SEResNet(SEBasicBlock, [3, 4, 6, 3], **kwargs)
    return model


def SEresnet50(**kwargs):
    model = SEResNet(SEBottleneck, [3, 4, 6, 3], **kwargs)
    return model


def SEresnet101(**kwargs):
    model = SEResNet(SEBottleneck, [3, 4, 23, 3], **kwargs)
    return model


def SEresnet152(**kwargs):
    model = SEResNet(Bottleneck, [3, 8, 36, 3], **kwargs)
    return model

# %%
net = SEresnet18().to(DEVICE)
criteon = nn.CrossEntropyLoss().to(DEVICE)
optimizer = optim.SGD(net.parameters(),
                      lr=learning_rate,
                      momentum=momentum,
                      )

scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, 'min', min_lr=1e-4, factor=0.1, patience=3)

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
summary(net, (3, 224, 224))
print(f'parameters_count: {count_parameters(net)}')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#        BasicConv2d-4         [-1, 64, 112, 112]               0
#          MaxPool2d-5           [-1, 64, 56, 56]               0
#             Conv2d-6           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-7           [-1, 64, 56, 56]             128
#               ReLU-8           [-1, 64, 56, 56]               0
#        BasicConv2d-9           [-1, 64, 56, 56]               0
#            Conv2d-10           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-11           [-1, 64, 56, 56]             128
#       BasicConv2d-12           [-1, 64, 56, 56]               0
# AdaptiveAvgPool2d-13             [-1, 64, 1, 1]               0
#            Linear-14                    [-1, 4]             256
#              ReLU-15                    [-1, 4]               0
#            Linear-16                   [-1, 64]             256
#           Sigmoid-17                   [-1, 64]               0
#           SEBlock-18           [-1, 64, 56, 56]               0
#      SEBasicBlock-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#       BasicConv2d-23           [-1, 64, 56, 56]               0
#            Conv2d-24           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-25           [-1, 64, 56, 56]             128
#       BasicConv2d-26           [-1, 64, 56, 56]               0
# AdaptiveAvgPool2d-27             [-1, 64, 1, 1]               0
#            Linear-28                    [-1, 4]             256
#              ReLU-29                    [-1, 4]               0
#            Linear-30                   [-1, 64]             256
#           Sigmoid-31                   [-1, 64]               0
#           SEBlock-32           [-1, 64, 56, 56]               0
#      SEBasicBlock-33           [-1, 64, 56, 56]               0
#            Conv2d-34          [-1, 128, 28, 28]           8,192
#       BatchNorm2d-35          [-1, 128, 28, 28]             256
#       BasicConv2d-36          [-1, 128, 28, 28]               0
#            Conv2d-37          [-1, 128, 28, 28]          73,728
#       BatchNorm2d-38          [-1, 128, 28, 28]             256
#              ReLU-39          [-1, 128, 28, 28]               0
#       BasicConv2d-40          [-1, 128, 28, 28]               0
#            Conv2d-41          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-42          [-1, 128, 28, 28]             256
#       BasicConv2d-43          [-1, 128, 28, 28]               0
# AdaptiveAvgPool2d-44            [-1, 128, 1, 1]               0
#            Linear-45                    [-1, 8]           1,024
#              ReLU-46                    [-1, 8]               0
#            Linear-47                  [-1, 128]           1,024
#           Sigmoid-48                  [-1, 128]               0
#           SEBlock-49          [-1, 128, 28, 28]               0
#      SEBasicBlock-50          [-1, 128, 28, 28]               0
#            Conv2d-51          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-52          [-1, 128, 28, 28]             256
#              ReLU-53          [-1, 128, 28, 28]               0
#       BasicConv2d-54          [-1, 128, 28, 28]               0
#            Conv2d-55          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-56          [-1, 128, 28, 28]             256
#       BasicConv2d-57          [-1, 128, 28, 28]               0
# AdaptiveAvgPool2d-58            [-1, 128, 1, 1]               0
#            Linear-59                    [-1, 8]           1,024
#              ReLU-60                    [-1, 8]               0
#            Linear-61                  [-1, 128]           1,024
#           Sigmoid-62                  [-1, 128]               0
#           SEBlock-63          [-1, 128, 28, 28]               0
#      SEBasicBlock-64          [-1, 128, 28, 28]               0
#            Conv2d-65          [-1, 256, 14, 14]          32,768
#       BatchNorm2d-66          [-1, 256, 14, 14]             512
#       BasicConv2d-67          [-1, 256, 14, 14]               0
#            Conv2d-68          [-1, 256, 14, 14]         294,912
#       BatchNorm2d-69          [-1, 256, 14, 14]             512
#              ReLU-70          [-1, 256, 14, 14]               0
#       BasicConv2d-71          [-1, 256, 14, 14]               0
#            Conv2d-72          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-73          [-1, 256, 14, 14]             512
#       BasicConv2d-74          [-1, 256, 14, 14]               0
# AdaptiveAvgPool2d-75            [-1, 256, 1, 1]               0
#            Linear-76                   [-1, 16]           4,096
#              ReLU-77                   [-1, 16]               0
#            Linear-78                  [-1, 256]           4,096
#           Sigmoid-79                  [-1, 256]               0
#           SEBlock-80          [-1, 256, 14, 14]               0
#      SEBasicBlock-81          [-1, 256, 14, 14]               0
#            Conv2d-82          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#              ReLU-84          [-1, 256, 14, 14]               0
#       BasicConv2d-85          [-1, 256, 14, 14]               0
#            Conv2d-86          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-87          [-1, 256, 14, 14]             512
#       BasicConv2d-88          [-1, 256, 14, 14]               0
# AdaptiveAvgPool2d-89            [-1, 256, 1, 1]               0
#            Linear-90                   [-1, 16]           4,096
#              ReLU-91                   [-1, 16]               0
#            Linear-92                  [-1, 256]           4,096
#           Sigmoid-93                  [-1, 256]               0
#           SEBlock-94          [-1, 256, 14, 14]               0
#      SEBasicBlock-95          [-1, 256, 14, 14]               0
#            Conv2d-96            [-1, 512, 7, 7]         131,072
#       BatchNorm2d-97            [-1, 512, 7, 7]           1,024
#       BasicConv2d-98            [-1, 512, 7, 7]               0
#            Conv2d-99            [-1, 512, 7, 7]       1,179,648
#      BatchNorm2d-100            [-1, 512, 7, 7]           1,024
#             ReLU-101            [-1, 512, 7, 7]               0
#      BasicConv2d-102            [-1, 512, 7, 7]               0
#           Conv2d-103            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-104            [-1, 512, 7, 7]           1,024
#      BasicConv2d-105            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-106            [-1, 512, 1, 1]               0
#           Linear-107                   [-1, 32]          16,384
#             ReLU-108                   [-1, 32]               0
#           Linear-109                  [-1, 512]          16,384
#          Sigmoid-110                  [-1, 512]               0
#          SEBlock-111            [-1, 512, 7, 7]               0
#     SEBasicBlock-112            [-1, 512, 7, 7]               0
#           Conv2d-113            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-114            [-1, 512, 7, 7]           1,024
#             ReLU-115            [-1, 512, 7, 7]               0
#      BasicConv2d-116            [-1, 512, 7, 7]               0
#           Conv2d-117            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-118            [-1, 512, 7, 7]           1,024
#      BasicConv2d-119            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-120            [-1, 512, 1, 1]               0
#           Linear-121                   [-1, 32]          16,384
#             ReLU-122                   [-1, 32]               0
#           Linear-123                  [-1, 512]          16,384
#          Sigmoid-124                  [-1, 512]               0
#          SEBlock-125            [-1, 512, 7, 7]               0
#     SEBasicBlock-126            [-1, 512, 7, 7]               0
#        AvgPool2d-127            [-1, 512, 1, 1]               0
#           Linear-128                   [-1, 10]           5,130
# ================================================================
# Total params: 11,268,682
# Trainable params: 11,268,682
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 81.78
# Params size (MB): 42.99
# Estimated Total Size (MB): 125.34
# ----------------------------------------------------------------
# parameters_count: 11268682

# %%
def train(epoch):
    train_loss = 0
    train_acc = 0
    train_correct = 0
    net.train()
    for batch_idx, (data, label) in enumerate(train_loader):
        data, label = data.to(DEVICE), label.to(DEVICE)

        logits = net(data)
        loss = criteon(logits, label)
        train_loss += loss.item()
        
        pred = torch.argmax(logits, dim=1)
        train_correct += torch.eq(pred, label).float().sum().item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch + 1, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
    
    train_loss /= len(val_loader.dataset)
    train_acc = 1. * train_correct / len(train_loader.dataset)

    return train_loss, train_acc

# %%
def validate():
    val_loss = 0
    val_acc = 0
    val_correct = 0
    net.eval()
    with torch.no_grad():
        for data, label in val_loader:
            data, label = data.to(DEVICE), label.to(DEVICE)

            logits = net(data)
            val_loss += criteon(logits, label).item()

            pred = torch.argmax(logits, dim=1)
            val_correct += torch.eq(pred, label).float().sum().item()

    val_loss /= len(val_loader.dataset)
    val_acc = 1. * val_correct / len(val_loader.dataset)

    print('VAL set: Average loss: {:.6f}, Accuracy: {}/{} ({:.1f}%)'.format(
        val_loss, val_correct, len(val_loader.dataset), 100. * val_acc))
    
    return val_loss, val_acc

# %%
def test():
    test_loss = 0
    test_acc = 0
    test_correct = 0
    net.eval()
    with torch.no_grad():
        for data, label in test_loader:
            data, label = data.to(DEVICE), label.to(DEVICE)

            logits = net(data)
            test_loss += criteon(logits, label).item()

            pred = torch.argmax(logits, dim=1)
            test_correct += torch.eq(pred, label).float().sum().item()

    test_loss /= len(test_loader.dataset)
    test_acc = 1. * test_correct / len(test_loader.dataset)

    print('\nTest set: Average loss: {:.6f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, test_correct, len(test_loader.dataset), 100. * test_acc))

# %%
def plot_loss(train_losses, valid_losses):
    plt.style.use('seaborn')
    fig, ax = plt.subplots(figsize=(8, 4.5))
    
    # find position of lowest validation loss
    minpos = valid_losses.index(min(valid_losses))

    train_losses = np.array(train_losses)
    valid_losses = np.array(valid_losses)

    ax.plot(train_losses, color='blue', label='Training loss')
    ax.plot(valid_losses, color='red', label='Validation loss')
    ax.set(title="Loss over epochs",
           xlabel='Epoch',
           ylabel='Loss')
    
    plt.axvline(minpos, linestyle='--', color='r',
                label='Early Stopping Checkpoint')
    ax.legend()

    # change the plot style to default
    plt.style.use('default')

# %%
def plot_acc(train_accuracies, validate_accuracies):
    plt.style.use('seaborn')
    fig, ax = plt.subplots(figsize=(8, 4.5))

    # find position of lowest validation loss
    maxpos = validate_accuracies.index(max(validate_accuracies))
    
    train_accuracies = np.array(train_accuracies)
    validate_accuracies = np.array(validate_accuracies)
    
    ax.plot(train_accuracies, color='blue', label='Training accuracy')
    ax.plot(validate_accuracies, color='red', label='Validation accuracy')
    ax.set(title="Accuracy over epochs",
           xlabel='Epoch',
           ylabel='Accuracy')
    
    plt.axvline(maxpos, linestyle='--', color='r',
                label='Early Stopping Checkpoint')
    ax.legend()

    # change the plot style to default
    plt.style.use('default')

# %%
def main():
    train_losses = []
    validate_losses = []
    train_accuracies = []
    validate_accuracies = []
    early_stopping = EarlyStopping(patience=patience, verbose=True)
    for epoch in range(epochs):
        train_loss, train_accuracy = train(epoch)
        train_losses.append(train_loss)
        train_accuracies.append(train_accuracy)
        validate_loss, validate_accuracy = validate()
        validate_losses.append(validate_loss)
        validate_accuracies.append(validate_accuracy)
        scheduler.step(validate_loss)
        early_stopping(val_loss=validate_loss, model=net)
        
        if early_stopping.early_stop:
            print("\nEarly stopping\n")
            break

    plot_loss(train_losses, validate_losses)
    plot_acc(train_accuracies, validate_accuracies)
    
    # load the last checkpoint with the best model
    net.load_state_dict(torch.load('checkpoint.pt'))

    test()

# %%
# %%time
if __name__ == '__main__':
    main()
# Out:
# Train Epoch: 1 [0/40000 (0%)]	Loss: 2.450639
# Train Epoch: 1 [3200/40000 (8%)]	Loss: 1.601285
# Train Epoch: 1 [6400/40000 (16%)]	Loss: 1.557768
# Train Epoch: 1 [9600/40000 (24%)]	Loss: 1.700126
# Train Epoch: 1 [12800/40000 (32%)]	Loss: 1.713022
# Train Epoch: 1 [16000/40000 (40%)]	Loss: 1.419556
# Train Epoch: 1 [19200/40000 (48%)]	Loss: 1.472512
# Train Epoch: 1 [22400/40000 (56%)]	Loss: 1.587565
# Train Epoch: 1 [25600/40000 (64%)]	Loss: 1.915553
# Train Epoch: 1 [28800/40000 (72%)]	Loss: 1.735991
# Train Epoch: 1 [32000/40000 (80%)]	Loss: 1.313355
# Train Epoch: 1 [35200/40000 (88%)]	Loss: 1.467150
# Train Epoch: 1 [38400/40000 (96%)]	Loss: 1.294845
# VAL set: Average loss: 0.044808, Accuracy: 4898.0/10000 (49.0%)
# Validation loss decreased (inf --> 0.044808).  Saving model ...
#
# Train Epoch: 2 [0/40000 (0%)]	Loss: 1.488745
# Train Epoch: 2 [3200/40000 (8%)]	Loss: 1.436758
# Train Epoch: 2 [6400/40000 (16%)]	Loss: 1.225011
# Train Epoch: 2 [9600/40000 (24%)]	Loss: 1.411067
# Train Epoch: 2 [12800/40000 (32%)]	Loss: 1.009790
# Train Epoch: 2 [16000/40000 (40%)]	Loss: 1.396811
# Train Epoch: 2 [19200/40000 (48%)]	Loss: 1.129976
# Train Epoch: 2 [22400/40000 (56%)]	Loss: 1.282974
# Train Epoch: 2 [25600/40000 (64%)]	Loss: 1.129349
# Train Epoch: 2 [28800/40000 (72%)]	Loss: 1.159338
# Train Epoch: 2 [32000/40000 (80%)]	Loss: 1.297997
# Train Epoch: 2 [35200/40000 (88%)]	Loss: 1.003651
# Train Epoch: 2 [38400/40000 (96%)]	Loss: 1.213643
# VAL set: Average loss: 0.037584, Accuracy: 5588.0/10000 (55.9%)
# Validation loss decreased (0.044808 --> 0.037584).  Saving model ...
#
# Train Epoch: 3 [0/40000 (0%)]	Loss: 1.052349
# Train Epoch: 3 [3200/40000 (8%)]	Loss: 0.911767
# Train Epoch: 3 [6400/40000 (16%)]	Loss: 1.098860
# Train Epoch: 3 [9600/40000 (24%)]	Loss: 1.090737
# Train Epoch: 3 [12800/40000 (32%)]	Loss: 1.082933
# Train Epoch: 3 [16000/40000 (40%)]	Loss: 0.895556
# Train Epoch: 3 [19200/40000 (48%)]	Loss: 0.919735
# Train Epoch: 3 [22400/40000 (56%)]	Loss: 0.708679
# Train Epoch: 3 [25600/40000 (64%)]	Loss: 1.282964
# Train Epoch: 3 [28800/40000 (72%)]	Loss: 1.074573
# Train Epoch: 3 [32000/40000 (80%)]	Loss: 1.496726
# Train Epoch: 3 [35200/40000 (88%)]	Loss: 1.006290
# Train Epoch: 3 [38400/40000 (96%)]	Loss: 0.686221
# VAL set: Average loss: 0.033367, Accuracy: 6197.0/10000 (62.0%)
# Validation loss decreased (0.037584 --> 0.033367).  Saving model ...
#
# Train Epoch: 4 [0/40000 (0%)]	Loss: 0.996369
# Train Epoch: 4 [3200/40000 (8%)]	Loss: 0.902237
# Train Epoch: 4 [6400/40000 (16%)]	Loss: 1.121114
# Train Epoch: 4 [9600/40000 (24%)]	Loss: 0.720533
# Train Epoch: 4 [12800/40000 (32%)]	Loss: 0.837919
# Train Epoch: 4 [16000/40000 (40%)]	Loss: 1.350583
# Train Epoch: 4 [19200/40000 (48%)]	Loss: 1.028955
# Train Epoch: 4 [22400/40000 (56%)]	Loss: 0.620836
# Train Epoch: 4 [25600/40000 (64%)]	Loss: 0.870259
# Train Epoch: 4 [28800/40000 (72%)]	Loss: 0.850863
# Train Epoch: 4 [32000/40000 (80%)]	Loss: 0.773585
# Train Epoch: 4 [35200/40000 (88%)]	Loss: 1.120546
# Train Epoch: 4 [38400/40000 (96%)]	Loss: 1.029014
# VAL set: Average loss: 0.030433, Accuracy: 6511.0/10000 (65.1%)
# Validation loss decreased (0.033367 --> 0.030433).  Saving model ...
#
# Train Epoch: 5 [0/40000 (0%)]	Loss: 0.816870
# Train Epoch: 5 [3200/40000 (8%)]	Loss: 1.178284
# Train Epoch: 5 [6400/40000 (16%)]	Loss: 0.901778
# Train Epoch: 5 [9600/40000 (24%)]	Loss: 1.026977
# Train Epoch: 5 [12800/40000 (32%)]	Loss: 1.037552
# Train Epoch: 5 [16000/40000 (40%)]	Loss: 1.108732
# Train Epoch: 5 [19200/40000 (48%)]	Loss: 0.920947
# Train Epoch: 5 [22400/40000 (56%)]	Loss: 0.739602
# Train Epoch: 5 [25600/40000 (64%)]	Loss: 1.477583
# Train Epoch: 5 [28800/40000 (72%)]	Loss: 0.824284
# Train Epoch: 5 [32000/40000 (80%)]	Loss: 0.623871
# Train Epoch: 5 [35200/40000 (88%)]	Loss: 0.760407
# Train Epoch: 5 [38400/40000 (96%)]	Loss: 0.524721
# VAL set: Average loss: 0.030318, Accuracy: 6621.0/10000 (66.2%)
# Validation loss decreased (0.030433 --> 0.030318).  Saving model ...
#
# Train Epoch: 6 [0/40000 (0%)]	Loss: 0.895464
# Train Epoch: 6 [3200/40000 (8%)]	Loss: 0.893192
# Train Epoch: 6 [6400/40000 (16%)]	Loss: 0.831611
# Train Epoch: 6 [9600/40000 (24%)]	Loss: 0.770173
# Train Epoch: 6 [12800/40000 (32%)]	Loss: 0.688091
# Train Epoch: 6 [16000/40000 (40%)]	Loss: 0.804732
# Train Epoch: 6 [19200/40000 (48%)]	Loss: 0.689147
# Train Epoch: 6 [22400/40000 (56%)]	Loss: 0.747901
# Train Epoch: 6 [25600/40000 (64%)]	Loss: 0.763020
# Train Epoch: 6 [28800/40000 (72%)]	Loss: 0.832445
# Train Epoch: 6 [32000/40000 (80%)]	Loss: 0.893371
# Train Epoch: 6 [35200/40000 (88%)]	Loss: 0.764037
# Train Epoch: 6 [38400/40000 (96%)]	Loss: 0.844147
# VAL set: Average loss: 0.026963, Accuracy: 6994.0/10000 (69.9%)
# Validation loss decreased (0.030318 --> 0.026963).  Saving model ...
#
# Train Epoch: 7 [0/40000 (0%)]	Loss: 0.875400
# Train Epoch: 7 [3200/40000 (8%)]	Loss: 0.896306
# Train Epoch: 7 [6400/40000 (16%)]	Loss: 1.099506
# Train Epoch: 7 [9600/40000 (24%)]	Loss: 0.872939
# Train Epoch: 7 [12800/40000 (32%)]	Loss: 0.828718
# Train Epoch: 7 [16000/40000 (40%)]	Loss: 1.099560
# Train Epoch: 7 [19200/40000 (48%)]	Loss: 0.905906
# Train Epoch: 7 [22400/40000 (56%)]	Loss: 1.306398
# Train Epoch: 7 [25600/40000 (64%)]	Loss: 0.447114
# Train Epoch: 7 [28800/40000 (72%)]	Loss: 0.531826
# Train Epoch: 7 [32000/40000 (80%)]	Loss: 0.861748
# Train Epoch: 7 [35200/40000 (88%)]	Loss: 1.005832
# Train Epoch: 7 [38400/40000 (96%)]	Loss: 0.653377
# VAL set: Average loss: 0.027079, Accuracy: 6989.0/10000 (69.9%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 8 [0/40000 (0%)]	Loss: 0.739457
# Train Epoch: 8 [3200/40000 (8%)]	Loss: 1.164490
# Train Epoch: 8 [6400/40000 (16%)]	Loss: 0.537577
# Train Epoch: 8 [9600/40000 (24%)]	Loss: 0.615116
# Train Epoch: 8 [12800/40000 (32%)]	Loss: 1.213054
# Train Epoch: 8 [16000/40000 (40%)]	Loss: 0.853068
# Train Epoch: 8 [19200/40000 (48%)]	Loss: 0.647872
# Train Epoch: 8 [22400/40000 (56%)]	Loss: 0.557919
# Train Epoch: 8 [25600/40000 (64%)]	Loss: 0.618991
# Train Epoch: 8 [28800/40000 (72%)]	Loss: 0.747808
# Train Epoch: 8 [32000/40000 (80%)]	Loss: 1.248812
# Train Epoch: 8 [35200/40000 (88%)]	Loss: 1.088304
# Train Epoch: 8 [38400/40000 (96%)]	Loss: 0.927484
# VAL set: Average loss: 0.022148, Accuracy: 7505.0/10000 (75.0%)
# Validation loss decreased (0.026963 --> 0.022148).  Saving model ...
#
# Train Epoch: 9 [0/40000 (0%)]	Loss: 0.552592
# Train Epoch: 9 [3200/40000 (8%)]	Loss: 0.492713
# Train Epoch: 9 [6400/40000 (16%)]	Loss: 0.682278
# Train Epoch: 9 [9600/40000 (24%)]	Loss: 0.708719
# Train Epoch: 9 [12800/40000 (32%)]	Loss: 1.013597
# Train Epoch: 9 [16000/40000 (40%)]	Loss: 0.541513
# Train Epoch: 9 [19200/40000 (48%)]	Loss: 0.760909
# Train Epoch: 9 [22400/40000 (56%)]	Loss: 0.656623
# Train Epoch: 9 [25600/40000 (64%)]	Loss: 0.474167
# Train Epoch: 9 [28800/40000 (72%)]	Loss: 1.037335
# Train Epoch: 9 [32000/40000 (80%)]	Loss: 0.402651
# Train Epoch: 9 [35200/40000 (88%)]	Loss: 0.991753
# Train Epoch: 9 [38400/40000 (96%)]	Loss: 1.118043
# VAL set: Average loss: 0.023716, Accuracy: 7397.0/10000 (74.0%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 10 [0/40000 (0%)]	Loss: 0.692781
# Train Epoch: 10 [3200/40000 (8%)]	Loss: 0.658706
# Train Epoch: 10 [6400/40000 (16%)]	Loss: 0.668219
# Train Epoch: 10 [9600/40000 (24%)]	Loss: 0.467948
# Train Epoch: 10 [12800/40000 (32%)]	Loss: 0.544259
# Train Epoch: 10 [16000/40000 (40%)]	Loss: 0.648309
# Train Epoch: 10 [19200/40000 (48%)]	Loss: 0.313861
# Train Epoch: 10 [22400/40000 (56%)]	Loss: 0.508971
# Train Epoch: 10 [25600/40000 (64%)]	Loss: 0.545687
# Train Epoch: 10 [28800/40000 (72%)]	Loss: 0.611735
# Train Epoch: 10 [32000/40000 (80%)]	Loss: 0.625467
# Train Epoch: 10 [35200/40000 (88%)]	Loss: 0.816392
# Train Epoch: 10 [38400/40000 (96%)]	Loss: 0.554849
# VAL set: Average loss: 0.021001, Accuracy: 7682.0/10000 (76.8%)
# Validation loss decreased (0.022148 --> 0.021001).  Saving model ...
#
# Train Epoch: 11 [0/40000 (0%)]	Loss: 1.196459
# Train Epoch: 11 [3200/40000 (8%)]	Loss: 0.312236
# Train Epoch: 11 [6400/40000 (16%)]	Loss: 0.683036
# Train Epoch: 11 [9600/40000 (24%)]	Loss: 0.322515
# Train Epoch: 11 [12800/40000 (32%)]	Loss: 0.390533
# Train Epoch: 11 [16000/40000 (40%)]	Loss: 0.845997
# Train Epoch: 11 [19200/40000 (48%)]	Loss: 0.191250
# Train Epoch: 11 [22400/40000 (56%)]	Loss: 0.450185
# Train Epoch: 11 [25600/40000 (64%)]	Loss: 0.514002
# Train Epoch: 11 [28800/40000 (72%)]	Loss: 0.590862
# Train Epoch: 11 [32000/40000 (80%)]	Loss: 0.759795
# Train Epoch: 11 [35200/40000 (88%)]	Loss: 0.655454
# Train Epoch: 11 [38400/40000 (96%)]	Loss: 0.668964
# VAL set: Average loss: 0.020470, Accuracy: 7700.0/10000 (77.0%)
# Validation loss decreased (0.021001 --> 0.020470).  Saving model ...
#
# Train Epoch: 12 [0/40000 (0%)]	Loss: 0.738380
# Train Epoch: 12 [3200/40000 (8%)]	Loss: 0.493703
# Train Epoch: 12 [6400/40000 (16%)]	Loss: 0.471629
# Train Epoch: 12 [9600/40000 (24%)]	Loss: 0.404401
# Train Epoch: 12 [12800/40000 (32%)]	Loss: 0.550780
# Train Epoch: 12 [16000/40000 (40%)]	Loss: 0.705945
# Train Epoch: 12 [19200/40000 (48%)]	Loss: 0.412481
# Train Epoch: 12 [22400/40000 (56%)]	Loss: 0.555505
# Train Epoch: 12 [25600/40000 (64%)]	Loss: 0.634497
# Train Epoch: 12 [28800/40000 (72%)]	Loss: 0.704893
# Train Epoch: 12 [32000/40000 (80%)]	Loss: 0.592610
# Train Epoch: 12 [35200/40000 (88%)]	Loss: 0.533183
# Train Epoch: 12 [38400/40000 (96%)]	Loss: 0.662480
# VAL set: Average loss: 0.022893, Accuracy: 7387.0/10000 (73.9%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 13 [0/40000 (0%)]	Loss: 0.480843
# Train Epoch: 13 [3200/40000 (8%)]	Loss: 0.630559
# Train Epoch: 13 [6400/40000 (16%)]	Loss: 0.995166
# Train Epoch: 13 [9600/40000 (24%)]	Loss: 0.424694
# Train Epoch: 13 [12800/40000 (32%)]	Loss: 0.411097
# Train Epoch: 13 [16000/40000 (40%)]	Loss: 0.523272
# Train Epoch: 13 [19200/40000 (48%)]	Loss: 0.737867
# Train Epoch: 13 [22400/40000 (56%)]	Loss: 0.798176
# Train Epoch: 13 [25600/40000 (64%)]	Loss: 0.645904
# Train Epoch: 13 [28800/40000 (72%)]	Loss: 0.572177
# Train Epoch: 13 [32000/40000 (80%)]	Loss: 0.582504
# Train Epoch: 13 [35200/40000 (88%)]	Loss: 0.448835
# Train Epoch: 13 [38400/40000 (96%)]	Loss: 0.644411
# VAL set: Average loss: 0.019718, Accuracy: 7784.0/10000 (77.8%)
# Validation loss decreased (0.020470 --> 0.019718).  Saving model ...
#
# Train Epoch: 14 [0/40000 (0%)]	Loss: 0.554608
# Train Epoch: 14 [3200/40000 (8%)]	Loss: 0.546348
# Train Epoch: 14 [6400/40000 (16%)]	Loss: 0.895702
# Train Epoch: 14 [9600/40000 (24%)]	Loss: 0.715493
# Train Epoch: 14 [12800/40000 (32%)]	Loss: 0.519471
# Train Epoch: 14 [16000/40000 (40%)]	Loss: 0.615638
# Train Epoch: 14 [19200/40000 (48%)]	Loss: 0.587986
# Train Epoch: 14 [22400/40000 (56%)]	Loss: 0.742961
# Train Epoch: 14 [25600/40000 (64%)]	Loss: 0.232587
# Train Epoch: 14 [28800/40000 (72%)]	Loss: 0.498093
# Train Epoch: 14 [32000/40000 (80%)]	Loss: 0.904975
# Train Epoch: 14 [35200/40000 (88%)]	Loss: 0.696375
# Train Epoch: 14 [38400/40000 (96%)]	Loss: 0.742480
# VAL set: Average loss: 0.020473, Accuracy: 7796.0/10000 (78.0%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 15 [0/40000 (0%)]	Loss: 0.660216
# Train Epoch: 15 [3200/40000 (8%)]	Loss: 0.699804
# Train Epoch: 15 [6400/40000 (16%)]	Loss: 0.728082
# Train Epoch: 15 [9600/40000 (24%)]	Loss: 0.600843
# Train Epoch: 15 [12800/40000 (32%)]	Loss: 0.379954
# Train Epoch: 15 [16000/40000 (40%)]	Loss: 0.701314
# Train Epoch: 15 [19200/40000 (48%)]	Loss: 0.594700
# Train Epoch: 15 [22400/40000 (56%)]	Loss: 0.236581
# Train Epoch: 15 [25600/40000 (64%)]	Loss: 0.792422
# Train Epoch: 15 [28800/40000 (72%)]	Loss: 0.579237
# Train Epoch: 15 [32000/40000 (80%)]	Loss: 0.511715
# Train Epoch: 15 [35200/40000 (88%)]	Loss: 0.492536
# Train Epoch: 15 [38400/40000 (96%)]	Loss: 0.448566
# VAL set: Average loss: 0.018718, Accuracy: 7914.0/10000 (79.1%)
# Validation loss decreased (0.019718 --> 0.018718).  Saving model ...
#
# Train Epoch: 16 [0/40000 (0%)]	Loss: 0.434720
# Train Epoch: 16 [3200/40000 (8%)]	Loss: 0.141161
# Train Epoch: 16 [6400/40000 (16%)]	Loss: 0.938402
# Train Epoch: 16 [9600/40000 (24%)]	Loss: 0.589903
# Train Epoch: 16 [12800/40000 (32%)]	Loss: 0.455319
# Train Epoch: 16 [16000/40000 (40%)]	Loss: 0.580363
# Train Epoch: 16 [19200/40000 (48%)]	Loss: 0.838664
# Train Epoch: 16 [22400/40000 (56%)]	Loss: 0.381915
# Train Epoch: 16 [25600/40000 (64%)]	Loss: 0.555210
# Train Epoch: 16 [28800/40000 (72%)]	Loss: 0.717359
# Train Epoch: 16 [32000/40000 (80%)]	Loss: 0.679060
# Train Epoch: 16 [35200/40000 (88%)]	Loss: 0.624767
# Train Epoch: 16 [38400/40000 (96%)]	Loss: 0.300442
# VAL set: Average loss: 0.018122, Accuracy: 7999.0/10000 (80.0%)
# Validation loss decreased (0.018718 --> 0.018122).  Saving model ...
#
# Train Epoch: 17 [0/40000 (0%)]	Loss: 0.562959
# Train Epoch: 17 [3200/40000 (8%)]	Loss: 0.285590
# Train Epoch: 17 [6400/40000 (16%)]	Loss: 0.239819
# Train Epoch: 17 [9600/40000 (24%)]	Loss: 0.368231
# Train Epoch: 17 [12800/40000 (32%)]	Loss: 0.702056
# Train Epoch: 17 [16000/40000 (40%)]	Loss: 0.595437
# Train Epoch: 17 [19200/40000 (48%)]	Loss: 0.561106
# Train Epoch: 17 [22400/40000 (56%)]	Loss: 0.431327
# Train Epoch: 17 [25600/40000 (64%)]	Loss: 0.148020
# Train Epoch: 17 [28800/40000 (72%)]	Loss: 0.280283
# Train Epoch: 17 [32000/40000 (80%)]	Loss: 0.439864
# Train Epoch: 17 [35200/40000 (88%)]	Loss: 0.477948
# Train Epoch: 17 [38400/40000 (96%)]	Loss: 0.505201
# VAL set: Average loss: 0.017823, Accuracy: 7997.0/10000 (80.0%)
# Validation loss decreased (0.018122 --> 0.017823).  Saving model ...
#
# Train Epoch: 18 [0/40000 (0%)]	Loss: 0.492715
# Train Epoch: 18 [3200/40000 (8%)]	Loss: 0.424982
# Train Epoch: 18 [6400/40000 (16%)]	Loss: 0.459807
# Train Epoch: 18 [9600/40000 (24%)]	Loss: 0.658969
# Train Epoch: 18 [12800/40000 (32%)]	Loss: 0.470652
# Train Epoch: 18 [16000/40000 (40%)]	Loss: 0.472940
# Train Epoch: 18 [19200/40000 (48%)]	Loss: 0.366935
# Train Epoch: 18 [22400/40000 (56%)]	Loss: 0.611906
# Train Epoch: 18 [25600/40000 (64%)]	Loss: 0.510718
# Train Epoch: 18 [28800/40000 (72%)]	Loss: 0.358382
# Train Epoch: 18 [32000/40000 (80%)]	Loss: 0.412525
# Train Epoch: 18 [35200/40000 (88%)]	Loss: 0.431456
# Train Epoch: 18 [38400/40000 (96%)]	Loss: 0.345783
# VAL set: Average loss: 0.017553, Accuracy: 8046.0/10000 (80.5%)
# Validation loss decreased (0.017823 --> 0.017553).  Saving model ...
#
# Train Epoch: 19 [0/40000 (0%)]	Loss: 0.438484
# Train Epoch: 19 [3200/40000 (8%)]	Loss: 0.340431
# Train Epoch: 19 [6400/40000 (16%)]	Loss: 0.588204
# Train Epoch: 19 [9600/40000 (24%)]	Loss: 0.377478
# Train Epoch: 19 [12800/40000 (32%)]	Loss: 0.628642
# Train Epoch: 19 [16000/40000 (40%)]	Loss: 0.579041
# Train Epoch: 19 [19200/40000 (48%)]	Loss: 0.748676
# Train Epoch: 19 [22400/40000 (56%)]	Loss: 0.416070
# Train Epoch: 19 [25600/40000 (64%)]	Loss: 0.463807
# Train Epoch: 19 [28800/40000 (72%)]	Loss: 0.299799
# Train Epoch: 19 [32000/40000 (80%)]	Loss: 0.753164
# Train Epoch: 19 [35200/40000 (88%)]	Loss: 0.528025
# Train Epoch: 19 [38400/40000 (96%)]	Loss: 0.333803
# VAL set: Average loss: 0.016587, Accuracy: 8176.0/10000 (81.8%)
# Validation loss decreased (0.017553 --> 0.016587).  Saving model ...
#
# Train Epoch: 20 [0/40000 (0%)]	Loss: 0.415831
# Train Epoch: 20 [3200/40000 (8%)]	Loss: 0.689540
# Train Epoch: 20 [6400/40000 (16%)]	Loss: 0.479541
# Train Epoch: 20 [9600/40000 (24%)]	Loss: 0.432674
# Train Epoch: 20 [12800/40000 (32%)]	Loss: 0.335982
# Train Epoch: 20 [16000/40000 (40%)]	Loss: 0.461208
# Train Epoch: 20 [19200/40000 (48%)]	Loss: 0.505504
# Train Epoch: 20 [22400/40000 (56%)]	Loss: 0.441053
# Train Epoch: 20 [25600/40000 (64%)]	Loss: 0.521782
# Train Epoch: 20 [28800/40000 (72%)]	Loss: 0.384043
# Train Epoch: 20 [32000/40000 (80%)]	Loss: 0.294686
# Train Epoch: 20 [35200/40000 (88%)]	Loss: 0.513275
# Train Epoch: 20 [38400/40000 (96%)]	Loss: 0.611378
# VAL set: Average loss: 0.016708, Accuracy: 8142.0/10000 (81.4%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 21 [0/40000 (0%)]	Loss: 0.401675
# Train Epoch: 21 [3200/40000 (8%)]	Loss: 0.441079
# Train Epoch: 21 [6400/40000 (16%)]	Loss: 0.461059
# Train Epoch: 21 [9600/40000 (24%)]	Loss: 0.724748
# Train Epoch: 21 [12800/40000 (32%)]	Loss: 0.453579
# Train Epoch: 21 [16000/40000 (40%)]	Loss: 0.407103
# Train Epoch: 21 [19200/40000 (48%)]	Loss: 0.236649
# Train Epoch: 21 [22400/40000 (56%)]	Loss: 0.477673
# Train Epoch: 21 [25600/40000 (64%)]	Loss: 0.332586
# Train Epoch: 21 [28800/40000 (72%)]	Loss: 0.335363
# Train Epoch: 21 [32000/40000 (80%)]	Loss: 0.569895
# Train Epoch: 21 [35200/40000 (88%)]	Loss: 0.436572
# Train Epoch: 21 [38400/40000 (96%)]	Loss: 0.239554
# VAL set: Average loss: 0.017825, Accuracy: 8053.0/10000 (80.5%)
# EarlyStopping counter: 2 out of 7
#
# Train Epoch: 22 [0/40000 (0%)]	Loss: 0.491745
# Train Epoch: 22 [3200/40000 (8%)]	Loss: 0.316670
# Train Epoch: 22 [6400/40000 (16%)]	Loss: 0.340325
# Train Epoch: 22 [9600/40000 (24%)]	Loss: 0.284329
# Train Epoch: 22 [12800/40000 (32%)]	Loss: 0.377080
# Train Epoch: 22 [16000/40000 (40%)]	Loss: 0.606932
# Train Epoch: 22 [19200/40000 (48%)]	Loss: 0.364261
# Train Epoch: 22 [22400/40000 (56%)]	Loss: 0.352246
# Train Epoch: 22 [25600/40000 (64%)]	Loss: 0.415031
# Train Epoch: 22 [28800/40000 (72%)]	Loss: 0.723870
# Train Epoch: 22 [32000/40000 (80%)]	Loss: 0.491758
# Train Epoch: 22 [35200/40000 (88%)]	Loss: 0.477557
# Train Epoch: 22 [38400/40000 (96%)]	Loss: 0.441569
# VAL set: Average loss: 0.015289, Accuracy: 8265.0/10000 (82.7%)
# Validation loss decreased (0.016587 --> 0.015289).  Saving model ...
#
# Train Epoch: 23 [0/40000 (0%)]	Loss: 0.244542
# Train Epoch: 23 [3200/40000 (8%)]	Loss: 0.379929
# Train Epoch: 23 [6400/40000 (16%)]	Loss: 0.342102
# Train Epoch: 23 [9600/40000 (24%)]	Loss: 0.189241
# Train Epoch: 23 [12800/40000 (32%)]	Loss: 0.353324
# Train Epoch: 23 [16000/40000 (40%)]	Loss: 0.398957
# Train Epoch: 23 [19200/40000 (48%)]	Loss: 0.305521
# Train Epoch: 23 [22400/40000 (56%)]	Loss: 0.161715
# Train Epoch: 23 [25600/40000 (64%)]	Loss: 0.179460
# Train Epoch: 23 [28800/40000 (72%)]	Loss: 0.667915
# Train Epoch: 23 [32000/40000 (80%)]	Loss: 0.368371
# Train Epoch: 23 [35200/40000 (88%)]	Loss: 0.259137
# Train Epoch: 23 [38400/40000 (96%)]	Loss: 0.417132
# VAL set: Average loss: 0.017052, Accuracy: 8171.0/10000 (81.7%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 24 [0/40000 (0%)]	Loss: 0.276427
# Train Epoch: 24 [3200/40000 (8%)]	Loss: 0.309667
# Train Epoch: 24 [6400/40000 (16%)]	Loss: 0.191036
# Train Epoch: 24 [9600/40000 (24%)]	Loss: 0.460802
# Train Epoch: 24 [12800/40000 (32%)]	Loss: 0.301520
# Train Epoch: 24 [16000/40000 (40%)]	Loss: 0.394188
# Train Epoch: 24 [19200/40000 (48%)]	Loss: 0.443179
# Train Epoch: 24 [22400/40000 (56%)]	Loss: 0.318175
# Train Epoch: 24 [25600/40000 (64%)]	Loss: 0.204327
# Train Epoch: 24 [28800/40000 (72%)]	Loss: 0.448105
# Train Epoch: 24 [32000/40000 (80%)]	Loss: 0.304468
# Train Epoch: 24 [35200/40000 (88%)]	Loss: 0.477706
# Train Epoch: 24 [38400/40000 (96%)]	Loss: 0.583957
# VAL set: Average loss: 0.014373, Accuracy: 8416.0/10000 (84.2%)
# Validation loss decreased (0.015289 --> 0.014373).  Saving model ...
#
# Train Epoch: 25 [0/40000 (0%)]	Loss: 0.197298
# Train Epoch: 25 [3200/40000 (8%)]	Loss: 0.356656
# Train Epoch: 25 [6400/40000 (16%)]	Loss: 0.211459
# Train Epoch: 25 [9600/40000 (24%)]	Loss: 0.228130
# Train Epoch: 25 [12800/40000 (32%)]	Loss: 0.373996
# Train Epoch: 25 [16000/40000 (40%)]	Loss: 0.575239
# Train Epoch: 25 [19200/40000 (48%)]	Loss: 0.344786
# Train Epoch: 25 [22400/40000 (56%)]	Loss: 0.375436
# Train Epoch: 25 [25600/40000 (64%)]	Loss: 0.311567
# Train Epoch: 25 [28800/40000 (72%)]	Loss: 0.321267
# Train Epoch: 25 [32000/40000 (80%)]	Loss: 0.491679
# Train Epoch: 25 [35200/40000 (88%)]	Loss: 0.338833
# Train Epoch: 25 [38400/40000 (96%)]	Loss: 0.384385
# VAL set: Average loss: 0.014881, Accuracy: 8391.0/10000 (83.9%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 26 [0/40000 (0%)]	Loss: 0.271179
# Train Epoch: 26 [3200/40000 (8%)]	Loss: 0.485157
# Train Epoch: 26 [6400/40000 (16%)]	Loss: 0.545935
# Train Epoch: 26 [9600/40000 (24%)]	Loss: 0.382428
# Train Epoch: 26 [12800/40000 (32%)]	Loss: 0.414045
# Train Epoch: 26 [16000/40000 (40%)]	Loss: 0.287452
# Train Epoch: 26 [19200/40000 (48%)]	Loss: 0.292847
# Train Epoch: 26 [22400/40000 (56%)]	Loss: 0.148747
# Train Epoch: 26 [25600/40000 (64%)]	Loss: 0.391686
# Train Epoch: 26 [28800/40000 (72%)]	Loss: 0.296351
# Train Epoch: 26 [32000/40000 (80%)]	Loss: 0.245967
# Train Epoch: 26 [35200/40000 (88%)]	Loss: 0.291052
# Train Epoch: 26 [38400/40000 (96%)]	Loss: 0.488130
# VAL set: Average loss: 0.015237, Accuracy: 8325.0/10000 (83.2%)
# EarlyStopping counter: 2 out of 7
#
# Train Epoch: 27 [0/40000 (0%)]	Loss: 0.297673
# Train Epoch: 27 [3200/40000 (8%)]	Loss: 0.460277
# Train Epoch: 27 [6400/40000 (16%)]	Loss: 0.342276
# Train Epoch: 27 [9600/40000 (24%)]	Loss: 0.542547
# Train Epoch: 27 [12800/40000 (32%)]	Loss: 0.271879
# Train Epoch: 27 [16000/40000 (40%)]	Loss: 0.641941
# Train Epoch: 27 [19200/40000 (48%)]	Loss: 0.214339
# Train Epoch: 27 [22400/40000 (56%)]	Loss: 0.525393
# Train Epoch: 27 [25600/40000 (64%)]	Loss: 0.306106
# Train Epoch: 27 [28800/40000 (72%)]	Loss: 0.813157
# Train Epoch: 27 [32000/40000 (80%)]	Loss: 0.205689
# Train Epoch: 27 [35200/40000 (88%)]	Loss: 0.252533
# Train Epoch: 27 [38400/40000 (96%)]	Loss: 0.364868
# VAL set: Average loss: 0.014254, Accuracy: 8416.0/10000 (84.2%)
# Validation loss decreased (0.014373 --> 0.014254).  Saving model ...
#
# Train Epoch: 28 [0/40000 (0%)]	Loss: 0.357758
# Train Epoch: 28 [3200/40000 (8%)]	Loss: 0.311559
# Train Epoch: 28 [6400/40000 (16%)]	Loss: 0.171221
# Train Epoch: 28 [9600/40000 (24%)]	Loss: 0.209325
# Train Epoch: 28 [12800/40000 (32%)]	Loss: 0.521810
# Train Epoch: 28 [16000/40000 (40%)]	Loss: 0.390108
# Train Epoch: 28 [19200/40000 (48%)]	Loss: 0.434270
# Train Epoch: 28 [22400/40000 (56%)]	Loss: 0.167387
# Train Epoch: 28 [25600/40000 (64%)]	Loss: 0.474764
# Train Epoch: 28 [28800/40000 (72%)]	Loss: 0.273228
# Train Epoch: 28 [32000/40000 (80%)]	Loss: 0.296670
# Train Epoch: 28 [35200/40000 (88%)]	Loss: 0.511600
# Train Epoch: 28 [38400/40000 (96%)]	Loss: 0.391010
# VAL set: Average loss: 0.016068, Accuracy: 8283.0/10000 (82.8%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 29 [0/40000 (0%)]	Loss: 0.219452
# Train Epoch: 29 [3200/40000 (8%)]	Loss: 0.135551
# Train Epoch: 29 [6400/40000 (16%)]	Loss: 0.148724
# Train Epoch: 29 [9600/40000 (24%)]	Loss: 0.461863
# Train Epoch: 29 [12800/40000 (32%)]	Loss: 0.128260
# Train Epoch: 29 [16000/40000 (40%)]	Loss: 0.187787
# Train Epoch: 29 [19200/40000 (48%)]	Loss: 0.093470
# Train Epoch: 29 [22400/40000 (56%)]	Loss: 0.174284
# Train Epoch: 29 [25600/40000 (64%)]	Loss: 0.525561
# Train Epoch: 29 [28800/40000 (72%)]	Loss: 0.270410
# Train Epoch: 29 [32000/40000 (80%)]	Loss: 0.167575
# Train Epoch: 29 [35200/40000 (88%)]	Loss: 0.377340
# Train Epoch: 29 [38400/40000 (96%)]	Loss: 0.410492
# VAL set: Average loss: 0.013686, Accuracy: 8490.0/10000 (84.9%)
# Validation loss decreased (0.014254 --> 0.013686).  Saving model ...
#
# Train Epoch: 30 [0/40000 (0%)]	Loss: 0.198903
# Train Epoch: 30 [3200/40000 (8%)]	Loss: 0.381692
# Train Epoch: 30 [6400/40000 (16%)]	Loss: 0.298792
# Train Epoch: 30 [9600/40000 (24%)]	Loss: 0.218941
# Train Epoch: 30 [12800/40000 (32%)]	Loss: 0.715942
# Train Epoch: 30 [16000/40000 (40%)]	Loss: 0.418513
# Train Epoch: 30 [19200/40000 (48%)]	Loss: 0.172828
# Train Epoch: 30 [22400/40000 (56%)]	Loss: 0.235929
# Train Epoch: 30 [25600/40000 (64%)]	Loss: 0.650279
# Train Epoch: 30 [28800/40000 (72%)]	Loss: 0.285318
# Train Epoch: 30 [32000/40000 (80%)]	Loss: 0.377716
# Train Epoch: 30 [35200/40000 (88%)]	Loss: 0.368736
# Train Epoch: 30 [38400/40000 (96%)]	Loss: 0.494429
# VAL set: Average loss: 0.013875, Accuracy: 8476.0/10000 (84.8%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 31 [0/40000 (0%)]	Loss: 0.113462
# Train Epoch: 31 [3200/40000 (8%)]	Loss: 0.269933
# Train Epoch: 31 [6400/40000 (16%)]	Loss: 0.515522
# Train Epoch: 31 [9600/40000 (24%)]	Loss: 0.321884
# Train Epoch: 31 [12800/40000 (32%)]	Loss: 0.088515
# Train Epoch: 31 [16000/40000 (40%)]	Loss: 0.358110
# Train Epoch: 31 [19200/40000 (48%)]	Loss: 0.481883
# Train Epoch: 31 [22400/40000 (56%)]	Loss: 0.300613
# Train Epoch: 31 [25600/40000 (64%)]	Loss: 0.622396
# Train Epoch: 31 [28800/40000 (72%)]	Loss: 0.361330
# Train Epoch: 31 [32000/40000 (80%)]	Loss: 0.463860
# Train Epoch: 31 [35200/40000 (88%)]	Loss: 0.143177
# Train Epoch: 31 [38400/40000 (96%)]	Loss: 0.542590
# VAL set: Average loss: 0.014409, Accuracy: 8428.0/10000 (84.3%)
# EarlyStopping counter: 2 out of 7
#
# Train Epoch: 32 [0/40000 (0%)]	Loss: 0.454429
# Train Epoch: 32 [3200/40000 (8%)]	Loss: 0.235760
# Train Epoch: 32 [6400/40000 (16%)]	Loss: 0.093536
# Train Epoch: 32 [9600/40000 (24%)]	Loss: 0.376167
# Train Epoch: 32 [12800/40000 (32%)]	Loss: 0.252875
# Train Epoch: 32 [16000/40000 (40%)]	Loss: 0.493041
# Train Epoch: 32 [19200/40000 (48%)]	Loss: 0.501419
# Train Epoch: 32 [22400/40000 (56%)]	Loss: 0.494283
# Train Epoch: 32 [25600/40000 (64%)]	Loss: 0.184003
# Train Epoch: 32 [28800/40000 (72%)]	Loss: 0.417638
# Train Epoch: 32 [32000/40000 (80%)]	Loss: 0.213458
# Train Epoch: 32 [35200/40000 (88%)]	Loss: 0.513808
# Train Epoch: 32 [38400/40000 (96%)]	Loss: 0.382443
# VAL set: Average loss: 0.013603, Accuracy: 8519.0/10000 (85.2%)
# Validation loss decreased (0.013686 --> 0.013603).  Saving model ...
#
# Train Epoch: 33 [0/40000 (0%)]	Loss: 0.273342
# Train Epoch: 33 [3200/40000 (8%)]	Loss: 0.093792
# Train Epoch: 33 [6400/40000 (16%)]	Loss: 0.239576
# Train Epoch: 33 [9600/40000 (24%)]	Loss: 0.222808
# Train Epoch: 33 [12800/40000 (32%)]	Loss: 0.072667
# Train Epoch: 33 [16000/40000 (40%)]	Loss: 0.241770
# Train Epoch: 33 [19200/40000 (48%)]	Loss: 0.285658
# Train Epoch: 33 [22400/40000 (56%)]	Loss: 0.352291
# Train Epoch: 33 [25600/40000 (64%)]	Loss: 0.355675
# Train Epoch: 33 [28800/40000 (72%)]	Loss: 0.439714
# Train Epoch: 33 [32000/40000 (80%)]	Loss: 0.258230
# Train Epoch: 33 [35200/40000 (88%)]	Loss: 0.412603
# Train Epoch: 33 [38400/40000 (96%)]	Loss: 0.239148
# VAL set: Average loss: 0.013244, Accuracy: 8537.0/10000 (85.4%)
# Validation loss decreased (0.013603 --> 0.013244).  Saving model ...
#
# Train Epoch: 34 [0/40000 (0%)]	Loss: 0.438206
# Train Epoch: 34 [3200/40000 (8%)]	Loss: 0.167224
# Train Epoch: 34 [6400/40000 (16%)]	Loss: 0.389222
# Train Epoch: 34 [9600/40000 (24%)]	Loss: 0.336880
# Train Epoch: 34 [12800/40000 (32%)]	Loss: 0.346999
# Train Epoch: 34 [16000/40000 (40%)]	Loss: 0.177078
# Train Epoch: 34 [19200/40000 (48%)]	Loss: 0.627676
# Train Epoch: 34 [22400/40000 (56%)]	Loss: 0.446535
# Train Epoch: 34 [25600/40000 (64%)]	Loss: 0.435216
# Train Epoch: 34 [28800/40000 (72%)]	Loss: 0.306219
# Train Epoch: 34 [32000/40000 (80%)]	Loss: 0.458790
# Train Epoch: 34 [35200/40000 (88%)]	Loss: 0.356582
# Train Epoch: 34 [38400/40000 (96%)]	Loss: 0.626272
# VAL set: Average loss: 0.013119, Accuracy: 8558.0/10000 (85.6%)
# Validation loss decreased (0.013244 --> 0.013119).  Saving model ...
#
# Train Epoch: 35 [0/40000 (0%)]	Loss: 0.173317
# Train Epoch: 35 [3200/40000 (8%)]	Loss: 0.334302
# Train Epoch: 35 [6400/40000 (16%)]	Loss: 0.221284
# Train Epoch: 35 [9600/40000 (24%)]	Loss: 0.376511
# Train Epoch: 35 [12800/40000 (32%)]	Loss: 0.224818
# Train Epoch: 35 [16000/40000 (40%)]	Loss: 0.227232
# Train Epoch: 35 [19200/40000 (48%)]	Loss: 0.338702
# Train Epoch: 35 [22400/40000 (56%)]	Loss: 0.338977
# Train Epoch: 35 [25600/40000 (64%)]	Loss: 0.238440
# Train Epoch: 35 [28800/40000 (72%)]	Loss: 0.252258
# Train Epoch: 35 [32000/40000 (80%)]	Loss: 0.237292
# Train Epoch: 35 [35200/40000 (88%)]	Loss: 0.281636
# Train Epoch: 35 [38400/40000 (96%)]	Loss: 0.307796
# VAL set: Average loss: 0.012839, Accuracy: 8615.0/10000 (86.2%)
# Validation loss decreased (0.013119 --> 0.012839).  Saving model ...
#
# Train Epoch: 36 [0/40000 (0%)]	Loss: 0.273409
# Train Epoch: 36 [3200/40000 (8%)]	Loss: 0.330516
# Train Epoch: 36 [6400/40000 (16%)]	Loss: 0.450086
# Train Epoch: 36 [9600/40000 (24%)]	Loss: 0.197669
# Train Epoch: 36 [12800/40000 (32%)]	Loss: 0.304965
# Train Epoch: 36 [16000/40000 (40%)]	Loss: 0.169728
# Train Epoch: 36 [19200/40000 (48%)]	Loss: 0.290982
# Train Epoch: 36 [22400/40000 (56%)]	Loss: 0.106204
# Train Epoch: 36 [25600/40000 (64%)]	Loss: 0.219443
# Train Epoch: 36 [28800/40000 (72%)]	Loss: 0.245054
# Train Epoch: 36 [32000/40000 (80%)]	Loss: 0.121276
# Train Epoch: 36 [35200/40000 (88%)]	Loss: 0.569172
# Train Epoch: 36 [38400/40000 (96%)]	Loss: 0.085600
# VAL set: Average loss: 0.013035, Accuracy: 8574.0/10000 (85.7%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 37 [0/40000 (0%)]	Loss: 0.678345
# Train Epoch: 37 [3200/40000 (8%)]	Loss: 0.531039
# Train Epoch: 37 [6400/40000 (16%)]	Loss: 0.163993
# Train Epoch: 37 [9600/40000 (24%)]	Loss: 0.226501
# Train Epoch: 37 [12800/40000 (32%)]	Loss: 0.603095
# Train Epoch: 37 [16000/40000 (40%)]	Loss: 0.085337
# Train Epoch: 37 [19200/40000 (48%)]	Loss: 0.248308
# Train Epoch: 37 [22400/40000 (56%)]	Loss: 0.236748
# Train Epoch: 37 [25600/40000 (64%)]	Loss: 0.082410
# Train Epoch: 37 [28800/40000 (72%)]	Loss: 0.120849
# Train Epoch: 37 [32000/40000 (80%)]	Loss: 0.389156
# Train Epoch: 37 [35200/40000 (88%)]	Loss: 0.261225
# Train Epoch: 37 [38400/40000 (96%)]	Loss: 0.283756
# VAL set: Average loss: 0.013260, Accuracy: 8568.0/10000 (85.7%)
# EarlyStopping counter: 2 out of 7
#
# Train Epoch: 38 [0/40000 (0%)]	Loss: 0.106779
# Train Epoch: 38 [3200/40000 (8%)]	Loss: 0.331431
# Train Epoch: 38 [6400/40000 (16%)]	Loss: 0.098087
# Train Epoch: 38 [9600/40000 (24%)]	Loss: 0.400396
# Train Epoch: 38 [12800/40000 (32%)]	Loss: 0.107253
# Train Epoch: 38 [16000/40000 (40%)]	Loss: 0.581537
# Train Epoch: 38 [19200/40000 (48%)]	Loss: 0.510525
# Train Epoch: 38 [22400/40000 (56%)]	Loss: 0.176371
# Train Epoch: 38 [25600/40000 (64%)]	Loss: 0.112457
# Train Epoch: 38 [28800/40000 (72%)]	Loss: 0.146731
# Train Epoch: 38 [32000/40000 (80%)]	Loss: 0.431982
# Train Epoch: 38 [35200/40000 (88%)]	Loss: 0.470809
# Train Epoch: 38 [38400/40000 (96%)]	Loss: 0.254862
# VAL set: Average loss: 0.013708, Accuracy: 8556.0/10000 (85.6%)
# EarlyStopping counter: 3 out of 7
#
# Train Epoch: 39 [0/40000 (0%)]	Loss: 0.191757
# Train Epoch: 39 [3200/40000 (8%)]	Loss: 0.158809
# Train Epoch: 39 [6400/40000 (16%)]	Loss: 0.375946
# Train Epoch: 39 [9600/40000 (24%)]	Loss: 0.377555
# Train Epoch: 39 [12800/40000 (32%)]	Loss: 0.349940
# Train Epoch: 39 [16000/40000 (40%)]	Loss: 0.189094
# Train Epoch: 39 [19200/40000 (48%)]	Loss: 0.321965
# Train Epoch: 39 [22400/40000 (56%)]	Loss: 0.074775
# Train Epoch: 39 [25600/40000 (64%)]	Loss: 0.178297
# Train Epoch: 39 [28800/40000 (72%)]	Loss: 0.359825
# Train Epoch: 39 [32000/40000 (80%)]	Loss: 0.532383
# Train Epoch: 39 [35200/40000 (88%)]	Loss: 0.356210
# Train Epoch: 39 [38400/40000 (96%)]	Loss: 0.121499
# VAL set: Average loss: 0.013207, Accuracy: 8559.0/10000 (85.6%)
# EarlyStopping counter: 4 out of 7
#
# Train Epoch: 40 [0/40000 (0%)]	Loss: 0.131412
# Train Epoch: 40 [3200/40000 (8%)]	Loss: 0.244699
# Train Epoch: 40 [6400/40000 (16%)]	Loss: 0.154331
# Train Epoch: 40 [9600/40000 (24%)]	Loss: 0.244434
# Train Epoch: 40 [12800/40000 (32%)]	Loss: 0.171081
# Train Epoch: 40 [16000/40000 (40%)]	Loss: 0.208095
# Train Epoch: 40 [19200/40000 (48%)]	Loss: 0.143766
# Train Epoch: 40 [22400/40000 (56%)]	Loss: 0.304003
# Train Epoch: 40 [25600/40000 (64%)]	Loss: 0.229735
# Train Epoch: 40 [28800/40000 (72%)]	Loss: 0.185079
# Train Epoch: 40 [32000/40000 (80%)]	Loss: 0.150065
# Train Epoch: 40 [35200/40000 (88%)]	Loss: 0.101025
# Train Epoch: 40 [38400/40000 (96%)]	Loss: 0.079205
# VAL set: Average loss: 0.010512, Accuracy: 8855.0/10000 (88.5%)
# Validation loss decreased (0.012839 --> 0.010512).  Saving model ...
#
# Train Epoch: 41 [0/40000 (0%)]	Loss: 0.103555
# Train Epoch: 41 [3200/40000 (8%)]	Loss: 0.036434
# Train Epoch: 41 [6400/40000 (16%)]	Loss: 0.100964
# Train Epoch: 41 [9600/40000 (24%)]	Loss: 0.107610
# Train Epoch: 41 [12800/40000 (32%)]	Loss: 0.187136
# Train Epoch: 41 [16000/40000 (40%)]	Loss: 0.092338
# Train Epoch: 41 [19200/40000 (48%)]	Loss: 0.096339
# Train Epoch: 41 [22400/40000 (56%)]	Loss: 0.273333
# Train Epoch: 41 [25600/40000 (64%)]	Loss: 0.086359
# Train Epoch: 41 [28800/40000 (72%)]	Loss: 0.211770
# Train Epoch: 41 [32000/40000 (80%)]	Loss: 0.174825
# Train Epoch: 41 [35200/40000 (88%)]	Loss: 0.160476
# Train Epoch: 41 [38400/40000 (96%)]	Loss: 0.203374
# VAL set: Average loss: 0.010555, Accuracy: 8872.0/10000 (88.7%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 42 [0/40000 (0%)]	Loss: 0.133755
# Train Epoch: 42 [3200/40000 (8%)]	Loss: 0.045656
# Train Epoch: 42 [6400/40000 (16%)]	Loss: 0.111083
# Train Epoch: 42 [9600/40000 (24%)]	Loss: 0.180915
# Train Epoch: 42 [12800/40000 (32%)]	Loss: 0.068513
# Train Epoch: 42 [16000/40000 (40%)]	Loss: 0.062975
# Train Epoch: 42 [19200/40000 (48%)]	Loss: 0.086493
# Train Epoch: 42 [22400/40000 (56%)]	Loss: 0.163300
# Train Epoch: 42 [25600/40000 (64%)]	Loss: 0.181528
# Train Epoch: 42 [28800/40000 (72%)]	Loss: 0.416612
# Train Epoch: 42 [32000/40000 (80%)]	Loss: 0.065353
# Train Epoch: 42 [35200/40000 (88%)]	Loss: 0.086119
# Train Epoch: 42 [38400/40000 (96%)]	Loss: 0.073191
# VAL set: Average loss: 0.010007, Accuracy: 8929.0/10000 (89.3%)
# Validation loss decreased (0.010512 --> 0.010007).  Saving model ...
#
# Train Epoch: 43 [0/40000 (0%)]	Loss: 0.199460
# Train Epoch: 43 [3200/40000 (8%)]	Loss: 0.232304
# Train Epoch: 43 [6400/40000 (16%)]	Loss: 0.206256
# Train Epoch: 43 [9600/40000 (24%)]	Loss: 0.081082
# Train Epoch: 43 [12800/40000 (32%)]	Loss: 0.201976
# Train Epoch: 43 [16000/40000 (40%)]	Loss: 0.124540
# Train Epoch: 43 [19200/40000 (48%)]	Loss: 0.057731
# Train Epoch: 43 [22400/40000 (56%)]	Loss: 0.175256
# Train Epoch: 43 [25600/40000 (64%)]	Loss: 0.139365
# Train Epoch: 43 [28800/40000 (72%)]	Loss: 0.195514
# Train Epoch: 43 [32000/40000 (80%)]	Loss: 0.151548
# Train Epoch: 43 [35200/40000 (88%)]	Loss: 0.102713
# Train Epoch: 43 [38400/40000 (96%)]	Loss: 0.238750
# VAL set: Average loss: 0.010138, Accuracy: 8894.0/10000 (88.9%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 44 [0/40000 (0%)]	Loss: 0.172299
# Train Epoch: 44 [3200/40000 (8%)]	Loss: 0.060826
# Train Epoch: 44 [6400/40000 (16%)]	Loss: 0.140525
# Train Epoch: 44 [9600/40000 (24%)]	Loss: 0.061385
# Train Epoch: 44 [12800/40000 (32%)]	Loss: 0.186534
# Train Epoch: 44 [16000/40000 (40%)]	Loss: 0.109018
# Train Epoch: 44 [19200/40000 (48%)]	Loss: 0.137112
# Train Epoch: 44 [22400/40000 (56%)]	Loss: 0.172568
# Train Epoch: 44 [25600/40000 (64%)]	Loss: 0.122613
# Train Epoch: 44 [28800/40000 (72%)]	Loss: 0.265164
# Train Epoch: 44 [32000/40000 (80%)]	Loss: 0.037963
# Train Epoch: 44 [35200/40000 (88%)]	Loss: 0.048427
# Train Epoch: 44 [38400/40000 (96%)]	Loss: 0.042260
# VAL set: Average loss: 0.010448, Accuracy: 8874.0/10000 (88.7%)
# EarlyStopping counter: 2 out of 7
#
# Train Epoch: 45 [0/40000 (0%)]	Loss: 0.129131
# Train Epoch: 45 [3200/40000 (8%)]	Loss: 0.125244
# Train Epoch: 45 [6400/40000 (16%)]	Loss: 0.053292
# Train Epoch: 45 [9600/40000 (24%)]	Loss: 0.346283
# Train Epoch: 45 [12800/40000 (32%)]	Loss: 0.119249
# Train Epoch: 45 [16000/40000 (40%)]	Loss: 0.169915
# Train Epoch: 45 [19200/40000 (48%)]	Loss: 0.261549
# Train Epoch: 45 [22400/40000 (56%)]	Loss: 0.143895
# Train Epoch: 45 [25600/40000 (64%)]	Loss: 0.191510
# Train Epoch: 45 [28800/40000 (72%)]	Loss: 0.153088
# Train Epoch: 45 [32000/40000 (80%)]	Loss: 0.272871
# Train Epoch: 45 [35200/40000 (88%)]	Loss: 0.100412
# Train Epoch: 45 [38400/40000 (96%)]	Loss: 0.170506
# VAL set: Average loss: 0.010256, Accuracy: 8917.0/10000 (89.2%)
# EarlyStopping counter: 3 out of 7
#
# Train Epoch: 46 [0/40000 (0%)]	Loss: 0.144460
# Train Epoch: 46 [3200/40000 (8%)]	Loss: 0.059107
# Train Epoch: 46 [6400/40000 (16%)]	Loss: 0.084271
# Train Epoch: 46 [9600/40000 (24%)]	Loss: 0.173371
# Train Epoch: 46 [12800/40000 (32%)]	Loss: 0.147550
# Train Epoch: 46 [16000/40000 (40%)]	Loss: 0.155126
# Train Epoch: 46 [19200/40000 (48%)]	Loss: 0.185050
# Train Epoch: 46 [22400/40000 (56%)]	Loss: 0.163027
# Train Epoch: 46 [25600/40000 (64%)]	Loss: 0.034944
# Train Epoch: 46 [28800/40000 (72%)]	Loss: 0.075270
# Train Epoch: 46 [32000/40000 (80%)]	Loss: 0.074996
# Train Epoch: 46 [35200/40000 (88%)]	Loss: 0.158123
# Train Epoch: 46 [38400/40000 (96%)]	Loss: 0.278902
# VAL set: Average loss: 0.010352, Accuracy: 8905.0/10000 (89.0%)
# EarlyStopping counter: 4 out of 7
#
# Train Epoch: 47 [0/40000 (0%)]	Loss: 0.159729
# Train Epoch: 47 [3200/40000 (8%)]	Loss: 0.156470
# Train Epoch: 47 [6400/40000 (16%)]	Loss: 0.093384
# Train Epoch: 47 [9600/40000 (24%)]	Loss: 0.207292
# Train Epoch: 47 [12800/40000 (32%)]	Loss: 0.117238
# Train Epoch: 47 [16000/40000 (40%)]	Loss: 0.155382
# Train Epoch: 47 [19200/40000 (48%)]	Loss: 0.189657
# Train Epoch: 47 [22400/40000 (56%)]	Loss: 0.029398
# Train Epoch: 47 [25600/40000 (64%)]	Loss: 0.191822
# Train Epoch: 47 [28800/40000 (72%)]	Loss: 0.116735
# Train Epoch: 47 [32000/40000 (80%)]	Loss: 0.083744
# Train Epoch: 47 [35200/40000 (88%)]	Loss: 0.144743
# Train Epoch: 47 [38400/40000 (96%)]	Loss: 0.078205
# VAL set: Average loss: 0.010470, Accuracy: 8879.0/10000 (88.8%)
# EarlyStopping counter: 5 out of 7
#
# Train Epoch: 48 [0/40000 (0%)]	Loss: 0.274286
# Train Epoch: 48 [3200/40000 (8%)]	Loss: 0.081052
# Train Epoch: 48 [6400/40000 (16%)]	Loss: 0.230759
# Train Epoch: 48 [9600/40000 (24%)]	Loss: 0.173377
# Train Epoch: 48 [12800/40000 (32%)]	Loss: 0.135736
# Train Epoch: 48 [16000/40000 (40%)]	Loss: 0.190828
# Train Epoch: 48 [19200/40000 (48%)]	Loss: 0.054619
# Train Epoch: 48 [22400/40000 (56%)]	Loss: 0.063104
# Train Epoch: 48 [25600/40000 (64%)]	Loss: 0.102911
# Train Epoch: 48 [28800/40000 (72%)]	Loss: 0.123417
# Train Epoch: 48 [32000/40000 (80%)]	Loss: 0.173757
# Train Epoch: 48 [35200/40000 (88%)]	Loss: 0.167871
# Train Epoch: 48 [38400/40000 (96%)]	Loss: 0.123692
# VAL set: Average loss: 0.010132, Accuracy: 8899.0/10000 (89.0%)
# EarlyStopping counter: 6 out of 7
#
# Train Epoch: 49 [0/40000 (0%)]	Loss: 0.091836
# Train Epoch: 49 [3200/40000 (8%)]	Loss: 0.077041
# Train Epoch: 49 [6400/40000 (16%)]	Loss: 0.045115
# Train Epoch: 49 [9600/40000 (24%)]	Loss: 0.031030
# Train Epoch: 49 [12800/40000 (32%)]	Loss: 0.056619
# Train Epoch: 49 [16000/40000 (40%)]	Loss: 0.147038
# Train Epoch: 49 [19200/40000 (48%)]	Loss: 0.192052
# Train Epoch: 49 [22400/40000 (56%)]	Loss: 0.112837
# Train Epoch: 49 [25600/40000 (64%)]	Loss: 0.047304
# Train Epoch: 49 [28800/40000 (72%)]	Loss: 0.089916
# Train Epoch: 49 [32000/40000 (80%)]	Loss: 0.061001
# Train Epoch: 49 [35200/40000 (88%)]	Loss: 0.137512
# Train Epoch: 49 [38400/40000 (96%)]	Loss: 0.138718
# VAL set: Average loss: 0.009937, Accuracy: 8908.0/10000 (89.1%)
# Validation loss decreased (0.010007 --> 0.009937).  Saving model ...
#
# Train Epoch: 50 [0/40000 (0%)]	Loss: 0.063972
# Train Epoch: 50 [3200/40000 (8%)]	Loss: 0.217439
# Train Epoch: 50 [6400/40000 (16%)]	Loss: 0.239708
# Train Epoch: 50 [9600/40000 (24%)]	Loss: 0.118350
# Train Epoch: 50 [12800/40000 (32%)]	Loss: 0.215639
# Train Epoch: 50 [16000/40000 (40%)]	Loss: 0.040450
# Train Epoch: 50 [19200/40000 (48%)]	Loss: 0.095127
# Train Epoch: 50 [22400/40000 (56%)]	Loss: 0.320417
# Train Epoch: 50 [25600/40000 (64%)]	Loss: 0.115208
# Train Epoch: 50 [28800/40000 (72%)]	Loss: 0.128133
# Train Epoch: 50 [32000/40000 (80%)]	Loss: 0.169172
# Train Epoch: 50 [35200/40000 (88%)]	Loss: 0.094150
# Train Epoch: 50 [38400/40000 (96%)]	Loss: 0.159734
# VAL set: Average loss: 0.010009, Accuracy: 8930.0/10000 (89.3%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 51 [0/40000 (0%)]	Loss: 0.097457
# Train Epoch: 51 [3200/40000 (8%)]	Loss: 0.281096
# Train Epoch: 51 [6400/40000 (16%)]	Loss: 0.120558
# Train Epoch: 51 [9600/40000 (24%)]	Loss: 0.208713
# Train Epoch: 51 [12800/40000 (32%)]	Loss: 0.191473
# Train Epoch: 51 [16000/40000 (40%)]	Loss: 0.059825
# Train Epoch: 51 [19200/40000 (48%)]	Loss: 0.052483
# Train Epoch: 51 [22400/40000 (56%)]	Loss: 0.148314
# Train Epoch: 51 [25600/40000 (64%)]	Loss: 0.198911
# Train Epoch: 51 [28800/40000 (72%)]	Loss: 0.074032
# Train Epoch: 51 [32000/40000 (80%)]	Loss: 0.056068
# Train Epoch: 51 [35200/40000 (88%)]	Loss: 0.078794
# Train Epoch: 51 [38400/40000 (96%)]	Loss: 0.164265
# VAL set: Average loss: 0.010041, Accuracy: 8924.0/10000 (89.2%)
# EarlyStopping counter: 2 out of 7
#
# Train Epoch: 52 [0/40000 (0%)]	Loss: 0.259739
# Train Epoch: 52 [3200/40000 (8%)]	Loss: 0.040525
# Train Epoch: 52 [6400/40000 (16%)]	Loss: 0.049621
# Train Epoch: 52 [9600/40000 (24%)]	Loss: 0.097587
# Train Epoch: 52 [12800/40000 (32%)]	Loss: 0.169235
# Train Epoch: 52 [16000/40000 (40%)]	Loss: 0.269025
# Train Epoch: 52 [19200/40000 (48%)]	Loss: 0.079750
# Train Epoch: 52 [22400/40000 (56%)]	Loss: 0.112544
# Train Epoch: 52 [25600/40000 (64%)]	Loss: 0.067165
# Train Epoch: 52 [28800/40000 (72%)]	Loss: 0.159380
# Train Epoch: 52 [32000/40000 (80%)]	Loss: 0.139249
# Train Epoch: 52 [35200/40000 (88%)]	Loss: 0.051454
# Train Epoch: 52 [38400/40000 (96%)]	Loss: 0.085746
# VAL set: Average loss: 0.010246, Accuracy: 8928.0/10000 (89.3%)
# EarlyStopping counter: 3 out of 7
#
# Train Epoch: 53 [0/40000 (0%)]	Loss: 0.207152
# Train Epoch: 53 [3200/40000 (8%)]	Loss: 0.117221
# Train Epoch: 53 [6400/40000 (16%)]	Loss: 0.033792
# Train Epoch: 53 [9600/40000 (24%)]	Loss: 0.196027
# Train Epoch: 53 [12800/40000 (32%)]	Loss: 0.091337
# Train Epoch: 53 [16000/40000 (40%)]	Loss: 0.193219
# Train Epoch: 53 [19200/40000 (48%)]	Loss: 0.150543
# Train Epoch: 53 [22400/40000 (56%)]	Loss: 0.111530
# Train Epoch: 53 [25600/40000 (64%)]	Loss: 0.146982
# Train Epoch: 53 [28800/40000 (72%)]	Loss: 0.059342
# Train Epoch: 53 [32000/40000 (80%)]	Loss: 0.039795
# Train Epoch: 53 [35200/40000 (88%)]	Loss: 0.028935
# Train Epoch: 53 [38400/40000 (96%)]	Loss: 0.060261
# VAL set: Average loss: 0.010022, Accuracy: 8913.0/10000 (89.1%)
# EarlyStopping counter: 4 out of 7
#
# Train Epoch: 54 [0/40000 (0%)]	Loss: 0.262725
# Train Epoch: 54 [3200/40000 (8%)]	Loss: 0.081340
# Train Epoch: 54 [6400/40000 (16%)]	Loss: 0.102623
# Train Epoch: 54 [9600/40000 (24%)]	Loss: 0.092037
# Train Epoch: 54 [12800/40000 (32%)]	Loss: 0.126824
# Train Epoch: 54 [16000/40000 (40%)]	Loss: 0.144912
# Train Epoch: 54 [19200/40000 (48%)]	Loss: 0.109426
# Train Epoch: 54 [22400/40000 (56%)]	Loss: 0.132126
# Train Epoch: 54 [25600/40000 (64%)]	Loss: 0.150478
# Train Epoch: 54 [28800/40000 (72%)]	Loss: 0.083968
# Train Epoch: 54 [32000/40000 (80%)]	Loss: 0.090305
# Train Epoch: 54 [35200/40000 (88%)]	Loss: 0.085473
# Train Epoch: 54 [38400/40000 (96%)]	Loss: 0.190339
# VAL set: Average loss: 0.009986, Accuracy: 8927.0/10000 (89.3%)
# EarlyStopping counter: 5 out of 7
#
# Train Epoch: 55 [0/40000 (0%)]	Loss: 0.096422
# Train Epoch: 55 [3200/40000 (8%)]	Loss: 0.085104
# Train Epoch: 55 [6400/40000 (16%)]	Loss: 0.032905
# Train Epoch: 55 [9600/40000 (24%)]	Loss: 0.131551
# Train Epoch: 55 [12800/40000 (32%)]	Loss: 0.085636
# Train Epoch: 55 [16000/40000 (40%)]	Loss: 0.235989
# Train Epoch: 55 [19200/40000 (48%)]	Loss: 0.050160
# Train Epoch: 55 [22400/40000 (56%)]	Loss: 0.289932
# Train Epoch: 55 [25600/40000 (64%)]	Loss: 0.251903
# Train Epoch: 55 [28800/40000 (72%)]	Loss: 0.123049
# Train Epoch: 55 [32000/40000 (80%)]	Loss: 0.024918
# Train Epoch: 55 [35200/40000 (88%)]	Loss: 0.173428
# Train Epoch: 55 [38400/40000 (96%)]	Loss: 0.085034
# VAL set: Average loss: 0.010204, Accuracy: 8922.0/10000 (89.2%)
# EarlyStopping counter: 6 out of 7
#
# Train Epoch: 56 [0/40000 (0%)]	Loss: 0.083908
# Train Epoch: 56 [3200/40000 (8%)]	Loss: 0.141339
# Train Epoch: 56 [6400/40000 (16%)]	Loss: 0.140999
# Train Epoch: 56 [9600/40000 (24%)]	Loss: 0.026561
# Train Epoch: 56 [12800/40000 (32%)]	Loss: 0.175560
# Train Epoch: 56 [16000/40000 (40%)]	Loss: 0.051835
# Train Epoch: 56 [19200/40000 (48%)]	Loss: 0.085184
# Train Epoch: 56 [22400/40000 (56%)]	Loss: 0.125171
# Train Epoch: 56 [25600/40000 (64%)]	Loss: 0.053415
# Train Epoch: 56 [28800/40000 (72%)]	Loss: 0.197689
# Train Epoch: 56 [32000/40000 (80%)]	Loss: 0.076995
# Train Epoch: 56 [35200/40000 (88%)]	Loss: 0.240269
# Train Epoch: 56 [38400/40000 (96%)]	Loss: 0.110679
# VAL set: Average loss: 0.010139, Accuracy: 8907.0/10000 (89.1%)
# EarlyStopping counter: 7 out of 7
#
#
# Early stopping
#
#
# Test set: Average loss: 0.010229, Accuracy: 8903.0/10000 (89%)
#
# CPU times: user 4h 34min 25s, sys: 5h 8min, total: 9h 42min 26s
# Wall time: 1h 40min 1s

# %%
CIFAR_dict = {0: 'airplane',
              1: 'automobile',
              2: 'brid',
              3: 'cat',
              4: 'deer',
              5: 'dog',
              6: 'frog',
              7: 'horse',
              8: 'ship',
              9: 'truck'}

ROW_IMG = 10
N_ROWS = 5

fig = plt.figure()
for index in range(1, ROW_IMG * N_ROWS + 1):
    plt.subplot(N_ROWS, ROW_IMG, index)
    plt.axis('off')
    plt.imshow(test_db.data[index])

    with torch.no_grad():
        net.eval()
        logits = net(test_db[index][0].unsqueeze(0).to(DEVICE))
        probs = F.softmax(logits, dim=1)

    title = f'{CIFAR_dict[int(torch.argmax(probs))]} ({torch.max(probs * 100):.0f}%)'

    plt.title(title, fontsize=4)

fig.suptitle('SEResNet-18 - predictions')
# Out:
# Text(0.5, 0.98, 'SEResNet-18 - predictions')

# %%
"""
MobileNetV1
Mine(batch_size = 32):
After 20 Epoch: 76.2%
After 40 Epoch: 83.1%
After 60 Epoch: 85.5%
After 80 Epoch: 87.3%
After 80 Epoch: 87.3%
structure:
==========================================================================================
Layer (type:depth-idx)                   Output Shape              Param #
==========================================================================================
├─Sequential: 1-1                        [-1, 1024, 1, 1]          --
|    └─BasicConv2d: 2-1                  [-1, 32, 111, 111]        --
|    |    └─Sequential: 3-1              [-1, 32, 111, 111]        960
|    └─DWConv2d: 2-2                     [-1, 64, 111, 111]        --
|    |    └─Sequential: 3-2              [-1, 64, 111, 111]        11,456
|    └─DWConv2d: 2-3                     [-1, 128, 56, 56]         --
|    |    └─Sequential: 3-3              [-1, 128, 56, 56]         45,440
|    └─DWConv2d: 2-4                     [-1, 128, 56, 56]         --
|    |    └─Sequential: 3-4              [-1, 128, 56, 56]         164,352
|    └─DWConv2d: 2-5                     [-1, 256, 28, 28]         --
|    |    └─Sequential: 3-5              [-1, 256, 28, 28]         180,992
|    └─DWConv2d: 2-6                     [-1, 256, 28, 28]         --
|    |    └─Sequential: 3-6              [-1, 256, 28, 28]         656,384
|    └─DWConv2d: 2-7                     [-1, 512, 14, 14]         --
|    |    └─Sequential: 3-7              [-1, 512, 14, 14]         722,432
|    └─DWConv2d: 2-8                     [-1, 512, 14, 14]         --
|    |    └─Sequential: 3-8              [-1, 512, 14, 14]         2,623,488
|    └─DWConv2d: 2-9                     [-1, 512, 14, 14]         --
|    |    └─Sequential: 3-9              [-1, 512, 14, 14]         2,623,488
|    └─DWConv2d: 2-10                    [-1, 512, 14, 14]         --
|    |    └─Sequential: 3-10             [-1, 512, 14, 14]         2,623,488
|    └─DWConv2d: 2-11                    [-1, 512, 14, 14]         --
|    |    └─Sequential: 3-11             [-1, 512, 14, 14]         2,623,488
|    └─DWConv2d: 2-12                    [-1, 512, 14, 14]         --
|    |    └─Sequential: 3-12             [-1, 512, 14, 14]         2,623,488
|    └─DWConv2d: 2-13                    [-1, 1024, 7, 7]          --
|    |    └─Sequential: 3-13             [-1, 1024, 7, 7]          2,886,656
|    └─DWConv2d: 2-14                    [-1, 1024, 7, 7]          --
|    |    └─Sequential: 3-14             [-1, 1024, 7, 7]          10,489,856
|    └─AvgPool2d: 2-15                   [-1, 1024, 1, 1]          --
├─Linear: 1-2                            [-1, 1000]                1,025,000
==========================================================================================
Total params: 29,300,968
Trainable params: 29,300,968
Non-trainable params: 0
Total mult-adds (M): 124.73
==========================================================================================
Input size (MB): 0.57
Forward/backward pass size (MB): 6.02
Params size (MB): 111.77
Estimated Total Size (MB): 118.37
==========================================================================================
parameters_count: 29300968
"""
