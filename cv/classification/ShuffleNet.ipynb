# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
import torch.optim as optim
import matplotlib.pyplot as plt
from collections import OrderedDict
from torchsummary import summary

# %matplotlib inline

# check device
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print("We use " + DEVICE)
torch.cuda.empty_cache()
# Out:
# We use cuda

# %%
batch_size = 64
learning_rate  = 1e-2
momentum = 0.5
epochs = 100
patience = 7

# %%
train_db = datasets.CIFAR10('datasets/cifar10',
                            train=True,
                            download=True,
                            transform=transforms.Compose([
                                transforms.Resize([256, 256]),
                                transforms.RandomCrop(224),
                                transforms.RandomHorizontalFlip(),
                                transforms.RandomVerticalFlip(),
                                transforms.RandomRotation(15),
                                transforms.ToTensor(),                       # 数据类型转化
                                transforms.Normalize(
                                    (0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))  # 数据归一化处理
                            ]))

test_db = datasets.CIFAR10('datasets/cifar10',
                           train=False,
                           download=True,
                           transform=transforms.Compose([
                               transforms.Resize([256, 256]),
                               transforms.RandomCrop(224),
                               transforms.RandomHorizontalFlip(),
                               transforms.RandomVerticalFlip(),
                               transforms.RandomRotation(15),
                               transforms.ToTensor(),
                               transforms.Normalize(
                                   (0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
                           ]))

print('train:', len(train_db), 'test:', len(test_db))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# train: 50000 test: 10000

# %%
train_db, val_db = torch.utils.data.random_split(train_db, [40000, 10000])

print('train:', len(train_db), 'validation:', len(val_db))
# Out:
# train: 40000 validation: 10000

# %%
train_loader = DataLoader(
    train_db,
    batch_size=batch_size,
    drop_last=True,
    shuffle=True
)

val_loader = DataLoader(
    val_db,
    batch_size=batch_size,
    drop_last=True,
    shuffle=False
)

test_loader = DataLoader(
    test_db,
    batch_size=batch_size,
    drop_last=True,
    shuffle=False
)

# %%
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print            
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}\n')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...\n')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %%
class BasicConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, relu=True, **kwargs):
        super(BasicConv2d, self).__init__()
        self.relu = relu
        if self.relu:
            self.feature = nn.Sequential(
                nn.Conv2d(in_channels=in_channels,
                          out_channels=out_channels, **kwargs),
                nn.BatchNorm2d(num_features=out_channels),
                nn.ReLU(inplace=True),
            )
        else:
            self.feature = nn.Sequential(
                nn.Conv2d(in_channels=in_channels,
                          out_channels=out_channels, **kwargs),
                nn.BatchNorm2d(num_features=out_channels),
            )

    def forward(self, x):
        out = self.feature(x)
        return out

# %%
class ShuffleBlock(nn.Module):
    def __init__(self, num_groups):
        super(ShuffleBlock, self).__init__()
        self.num_groups = num_groups

    def forward(self, x):
        out = self.shuffle_channel(x, self.num_groups)
        return out
    
    def shuffle_channel(self, x, num_groups):
        batch_size, num_channels, height, width = x.size()
        assert num_channels % num_groups == 0

        x = x.view(batch_size, num_groups, num_channels // self.num_groups, height, width)
        x = x.permute(0, 2, 1, 3, 4)
        return x.contiguous().view(batch_size, num_channels, height, width)

# %%
class ShuffleUnit(nn.Module):
    def __init__(self, in_channels, out_channels, num_groups, stride):
        super(ShuffleUnit, self).__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.bottleneck_channel = in_channels//4
        self.num_groups = num_groups
        self.stride = stride
        self.shuffle_unit = self._make_shuffle_unit(stride=self.stride)

    def forward(self, x):
        residual = x
        if self.stride == 1:
            return F.relu(input=(residual+self.shuffle_unit(x)), inplace=True)
        elif self.stride == 2:
            residual = F.avg_pool2d(
                input=residual, kernel_size=3, stride=2, padding=1)
            out = self.shuffle_unit(x)
            out = torch.cat((residual, out), dim=1)
            return F.relu(input=out, inplace=True)

    def _make_shuffle_unit(self, stride):
        shuffle_unit = nn.Sequential(
            BasicConv2d(in_channels=self.in_channels, out_channels=self.bottleneck_channel, relu=True,
                        kernel_size=1, stride=1, padding=0, groups=self.num_groups),
            ShuffleBlock(num_groups=self.num_groups),
            BasicConv2d(in_channels=self.bottleneck_channel, out_channels=self.bottleneck_channel,
                        relu=False, kernel_size=3, stride=stride, padding=1, groups=self.bottleneck_channel),
            BasicConv2d(in_channels=self.bottleneck_channel, out_channels=self.out_channels, relu=False,
                        kernel_size=1, stride=1, padding=0, groups=self.num_groups),
        )
        return shuffle_unit

# %%
class ShuffleNet(nn.Module):
    def __init__(self, ong, num_classes=10):
        super(ShuffleNet, self).__init__()
        self.in_channels = 24
        self.out_channels = ong['out_channels']
        self.num_blocks = ong['num_blocks']
        self.num_groups = ong['num_groups']

        self.stage1 = nn.Sequential(
            BasicConv2d(in_channels=3, out_channels=24, relu=True,
                        kernel_size=3, stride=2, padding=1, bias=False),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
        )
        self.stage2 = self._make_layer(
            out_channels=self.out_channels[0], num_blocks=self.num_blocks[0], num_groups=self.num_groups)
        self.stage3 = self._make_layer(
            out_channels=self.out_channels[1], num_blocks=self.num_blocks[1], num_groups=self.num_groups)
        self.stage4 = self._make_layer(
            out_channels=self.out_channels[2], num_blocks=self.num_blocks[2], num_groups=self.num_groups)
        self.globalpool = nn.AvgPool2d(kernel_size=7)
        self.fc = nn.Linear(
            in_features=self.out_channels[2], out_features=num_classes)

    def _make_layer(self, out_channels, num_blocks, num_groups):
        layers = []
        for i in range(num_blocks):
            if i == 0:
                layers.append(ShuffleUnit(in_channels=self.in_channels,
                                          out_channels=out_channels-self.in_channels,
                                          num_groups=num_groups, stride=2))
            else:
                layers.append(ShuffleUnit(in_channels=self.in_channels,
                                          out_channels=out_channels,
                                          num_groups=num_groups, stride=1))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.stage1(x)
        out = self.stage2(out)
        out = self.stage3(out)
        out = self.stage4(out)
        out = self.globalpool(out)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out

# %%
def ShuffleNetG1(num_classes=10):
    ong = {
        'out_channels': [144, 288, 576],
        'num_blocks': [3, 7, 3],
        'num_groups': 1
    }
    return ShuffleNet(ong, num_classes)


def ShuffleNetG2(num_classes=10):
    ong = {
        'out_channels': [200, 400, 800],
        'num_blocks': [3, 7, 3],
        'num_groups': 2
    }
    return ShuffleNet(ong, num_classes)


def ShuffleNetG3(num_classes=10):
    ong = {
        'out_channels': [240, 480, 960],
        'num_blocks': [3, 7, 3],
        'num_groups': 3
    }
    return ShuffleNet(ong, num_classes)

# %%
net = ShuffleNetG2().to(DEVICE)
criteon = nn.CrossEntropyLoss().to(DEVICE)
optimizer = optim.SGD(net.parameters(),
                      lr=learning_rate,
                      momentum=momentum,
                      )

scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, 'min', min_lr=1e-4, factor=0.3, patience=3)

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
summary(net, (3, 224, 224))
print(f'parameters_count: {count_parameters(net)}')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 24, 112, 112]             648
#        BatchNorm2d-2         [-1, 24, 112, 112]              48
#               ReLU-3         [-1, 24, 112, 112]               0
#        BasicConv2d-4         [-1, 24, 112, 112]               0
#          MaxPool2d-5           [-1, 24, 56, 56]               0
#             Conv2d-6            [-1, 6, 56, 56]              78
#        BatchNorm2d-7            [-1, 6, 56, 56]              12
#               ReLU-8            [-1, 6, 56, 56]               0
#        BasicConv2d-9            [-1, 6, 56, 56]               0
#      ShuffleBlock-10            [-1, 6, 56, 56]               0
#            Conv2d-11            [-1, 6, 28, 28]              60
#       BatchNorm2d-12            [-1, 6, 28, 28]              12
#       BasicConv2d-13            [-1, 6, 28, 28]               0
#            Conv2d-14          [-1, 176, 28, 28]             704
#       BatchNorm2d-15          [-1, 176, 28, 28]             352
#       BasicConv2d-16          [-1, 176, 28, 28]               0
#       ShuffleUnit-17          [-1, 200, 28, 28]               0
#            Conv2d-18           [-1, 50, 28, 28]           5,050
#       BatchNorm2d-19           [-1, 50, 28, 28]             100
#              ReLU-20           [-1, 50, 28, 28]               0
#       BasicConv2d-21           [-1, 50, 28, 28]               0
#      ShuffleBlock-22           [-1, 50, 28, 28]               0
#            Conv2d-23           [-1, 50, 28, 28]             500
#       BatchNorm2d-24           [-1, 50, 28, 28]             100
#       BasicConv2d-25           [-1, 50, 28, 28]               0
#            Conv2d-26          [-1, 200, 28, 28]           5,200
#       BatchNorm2d-27          [-1, 200, 28, 28]             400
#       BasicConv2d-28          [-1, 200, 28, 28]               0
#       ShuffleUnit-29          [-1, 200, 28, 28]               0
#            Conv2d-30           [-1, 50, 28, 28]           5,050
#       BatchNorm2d-31           [-1, 50, 28, 28]             100
#              ReLU-32           [-1, 50, 28, 28]               0
#       BasicConv2d-33           [-1, 50, 28, 28]               0
#      ShuffleBlock-34           [-1, 50, 28, 28]               0
#            Conv2d-35           [-1, 50, 28, 28]             500
#       BatchNorm2d-36           [-1, 50, 28, 28]             100
#       BasicConv2d-37           [-1, 50, 28, 28]               0
#            Conv2d-38          [-1, 200, 28, 28]           5,200
#       BatchNorm2d-39          [-1, 200, 28, 28]             400
#       BasicConv2d-40          [-1, 200, 28, 28]               0
#       ShuffleUnit-41          [-1, 200, 28, 28]               0
#            Conv2d-42           [-1, 50, 28, 28]           5,050
#       BatchNorm2d-43           [-1, 50, 28, 28]             100
#              ReLU-44           [-1, 50, 28, 28]               0
#       BasicConv2d-45           [-1, 50, 28, 28]               0
#      ShuffleBlock-46           [-1, 50, 28, 28]               0
#            Conv2d-47           [-1, 50, 14, 14]             500
#       BatchNorm2d-48           [-1, 50, 14, 14]             100
#       BasicConv2d-49           [-1, 50, 14, 14]               0
#            Conv2d-50          [-1, 200, 14, 14]           5,200
#       BatchNorm2d-51          [-1, 200, 14, 14]             400
#       BasicConv2d-52          [-1, 200, 14, 14]               0
#       ShuffleUnit-53          [-1, 400, 14, 14]               0
#            Conv2d-54          [-1, 100, 14, 14]          20,100
#       BatchNorm2d-55          [-1, 100, 14, 14]             200
#              ReLU-56          [-1, 100, 14, 14]               0
#       BasicConv2d-57          [-1, 100, 14, 14]               0
#      ShuffleBlock-58          [-1, 100, 14, 14]               0
#            Conv2d-59          [-1, 100, 14, 14]           1,000
#       BatchNorm2d-60          [-1, 100, 14, 14]             200
#       BasicConv2d-61          [-1, 100, 14, 14]               0
#            Conv2d-62          [-1, 400, 14, 14]          20,400
#       BatchNorm2d-63          [-1, 400, 14, 14]             800
#       BasicConv2d-64          [-1, 400, 14, 14]               0
#       ShuffleUnit-65          [-1, 400, 14, 14]               0
#            Conv2d-66          [-1, 100, 14, 14]          20,100
#       BatchNorm2d-67          [-1, 100, 14, 14]             200
#              ReLU-68          [-1, 100, 14, 14]               0
#       BasicConv2d-69          [-1, 100, 14, 14]               0
#      ShuffleBlock-70          [-1, 100, 14, 14]               0
#            Conv2d-71          [-1, 100, 14, 14]           1,000
#       BatchNorm2d-72          [-1, 100, 14, 14]             200
#       BasicConv2d-73          [-1, 100, 14, 14]               0
#            Conv2d-74          [-1, 400, 14, 14]          20,400
#       BatchNorm2d-75          [-1, 400, 14, 14]             800
#       BasicConv2d-76          [-1, 400, 14, 14]               0
#       ShuffleUnit-77          [-1, 400, 14, 14]               0
#            Conv2d-78          [-1, 100, 14, 14]          20,100
#       BatchNorm2d-79          [-1, 100, 14, 14]             200
#              ReLU-80          [-1, 100, 14, 14]               0
#       BasicConv2d-81          [-1, 100, 14, 14]               0
#      ShuffleBlock-82          [-1, 100, 14, 14]               0
#            Conv2d-83          [-1, 100, 14, 14]           1,000
#       BatchNorm2d-84          [-1, 100, 14, 14]             200
#       BasicConv2d-85          [-1, 100, 14, 14]               0
#            Conv2d-86          [-1, 400, 14, 14]          20,400
#       BatchNorm2d-87          [-1, 400, 14, 14]             800
#       BasicConv2d-88          [-1, 400, 14, 14]               0
#       ShuffleUnit-89          [-1, 400, 14, 14]               0
#            Conv2d-90          [-1, 100, 14, 14]          20,100
#       BatchNorm2d-91          [-1, 100, 14, 14]             200
#              ReLU-92          [-1, 100, 14, 14]               0
#       BasicConv2d-93          [-1, 100, 14, 14]               0
#      ShuffleBlock-94          [-1, 100, 14, 14]               0
#            Conv2d-95          [-1, 100, 14, 14]           1,000
#       BatchNorm2d-96          [-1, 100, 14, 14]             200
#       BasicConv2d-97          [-1, 100, 14, 14]               0
#            Conv2d-98          [-1, 400, 14, 14]          20,400
#       BatchNorm2d-99          [-1, 400, 14, 14]             800
#      BasicConv2d-100          [-1, 400, 14, 14]               0
#      ShuffleUnit-101          [-1, 400, 14, 14]               0
#           Conv2d-102          [-1, 100, 14, 14]          20,100
#      BatchNorm2d-103          [-1, 100, 14, 14]             200
#             ReLU-104          [-1, 100, 14, 14]               0
#      BasicConv2d-105          [-1, 100, 14, 14]               0
#     ShuffleBlock-106          [-1, 100, 14, 14]               0
#           Conv2d-107          [-1, 100, 14, 14]           1,000
#      BatchNorm2d-108          [-1, 100, 14, 14]             200
#      BasicConv2d-109          [-1, 100, 14, 14]               0
#           Conv2d-110          [-1, 400, 14, 14]          20,400
#      BatchNorm2d-111          [-1, 400, 14, 14]             800
#      BasicConv2d-112          [-1, 400, 14, 14]               0
#      ShuffleUnit-113          [-1, 400, 14, 14]               0
#           Conv2d-114          [-1, 100, 14, 14]          20,100
#      BatchNorm2d-115          [-1, 100, 14, 14]             200
#             ReLU-116          [-1, 100, 14, 14]               0
#      BasicConv2d-117          [-1, 100, 14, 14]               0
#     ShuffleBlock-118          [-1, 100, 14, 14]               0
#           Conv2d-119          [-1, 100, 14, 14]           1,000
#      BatchNorm2d-120          [-1, 100, 14, 14]             200
#      BasicConv2d-121          [-1, 100, 14, 14]               0
#           Conv2d-122          [-1, 400, 14, 14]          20,400
#      BatchNorm2d-123          [-1, 400, 14, 14]             800
#      BasicConv2d-124          [-1, 400, 14, 14]               0
#      ShuffleUnit-125          [-1, 400, 14, 14]               0
#           Conv2d-126          [-1, 100, 14, 14]          20,100
#      BatchNorm2d-127          [-1, 100, 14, 14]             200
#             ReLU-128          [-1, 100, 14, 14]               0
#      BasicConv2d-129          [-1, 100, 14, 14]               0
#     ShuffleBlock-130          [-1, 100, 14, 14]               0
#           Conv2d-131            [-1, 100, 7, 7]           1,000
#      BatchNorm2d-132            [-1, 100, 7, 7]             200
#      BasicConv2d-133            [-1, 100, 7, 7]               0
#           Conv2d-134            [-1, 400, 7, 7]          20,400
#      BatchNorm2d-135            [-1, 400, 7, 7]             800
#      BasicConv2d-136            [-1, 400, 7, 7]               0
#      ShuffleUnit-137            [-1, 800, 7, 7]               0
#           Conv2d-138            [-1, 200, 7, 7]          80,200
#      BatchNorm2d-139            [-1, 200, 7, 7]             400
#             ReLU-140            [-1, 200, 7, 7]               0
#      BasicConv2d-141            [-1, 200, 7, 7]               0
#     ShuffleBlock-142            [-1, 200, 7, 7]               0
#           Conv2d-143            [-1, 200, 7, 7]           2,000
#      BatchNorm2d-144            [-1, 200, 7, 7]             400
#      BasicConv2d-145            [-1, 200, 7, 7]               0
#           Conv2d-146            [-1, 800, 7, 7]          80,800
#      BatchNorm2d-147            [-1, 800, 7, 7]           1,600
#      BasicConv2d-148            [-1, 800, 7, 7]               0
#      ShuffleUnit-149            [-1, 800, 7, 7]               0
#           Conv2d-150            [-1, 200, 7, 7]          80,200
#      BatchNorm2d-151            [-1, 200, 7, 7]             400
#             ReLU-152            [-1, 200, 7, 7]               0
#      BasicConv2d-153            [-1, 200, 7, 7]               0
#     ShuffleBlock-154            [-1, 200, 7, 7]               0
#           Conv2d-155            [-1, 200, 7, 7]           2,000
#      BatchNorm2d-156            [-1, 200, 7, 7]             400
#      BasicConv2d-157            [-1, 200, 7, 7]               0
#           Conv2d-158            [-1, 800, 7, 7]          80,800
#      BatchNorm2d-159            [-1, 800, 7, 7]           1,600
#      BasicConv2d-160            [-1, 800, 7, 7]               0
#      ShuffleUnit-161            [-1, 800, 7, 7]               0
#        AvgPool2d-162            [-1, 800, 1, 1]               0
#           Linear-163                   [-1, 10]           8,010
# ================================================================
# Total params: 673,674
# Trainable params: 673,674
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 59.25
# Params size (MB): 2.57
# Estimated Total Size (MB): 62.39
# ----------------------------------------------------------------
# parameters_count: 673674

# %%
def train(epoch):
    train_loss = 0
    train_acc = 0
    train_correct = 0
    net.train()
    for batch_idx, (data, label) in enumerate(train_loader):
        data, label = data.to(DEVICE), label.to(DEVICE)

        logits = net(data)
        loss = criteon(logits, label)
        train_loss += loss.item()
        
        pred = torch.argmax(logits, dim=1)
        train_correct += torch.eq(pred, label).float().sum().item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch + 1, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
    
    train_loss /= len(val_loader.dataset)
    train_acc = 1. * train_correct / len(train_loader.dataset)

    return train_loss, train_acc

# %%
def validate():
    val_loss = 0
    val_acc = 0
    val_correct = 0
    net.eval()
    with torch.no_grad():
        for data, label in val_loader:
            data, label = data.to(DEVICE), label.to(DEVICE)

            logits = net(data)
            val_loss += criteon(logits, label).item()

            pred = torch.argmax(logits, dim=1)
            val_correct += torch.eq(pred, label).float().sum().item()
            

    val_loss /= len(val_loader.dataset)
    val_acc = 1. * val_correct / len(val_loader.dataset)

    print('VAL set: Average loss: {:.6f}, Accuracy: {}/{} ({:.1f}%)'.format(
        val_loss, val_correct, len(val_loader.dataset), 100. * val_acc))
    
    return val_loss, val_acc

# %%
def test():
    test_loss = 0
    test_acc = 0
    test_correct = 0
    net.eval()
    with torch.no_grad():
        for data, label in test_loader:
            data, label = data.to(DEVICE), label.to(DEVICE)

            logits = net(data)
            test_loss += criteon(logits, label).item()

            pred = torch.argmax(logits, dim=1)
            test_correct += torch.eq(pred, label).float().sum().item()

    test_loss /= len(test_loader.dataset)
    test_acc = 1. * test_correct / len(test_loader.dataset)

    print('\nTest set: Average loss: {:.6f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, test_correct, len(test_loader.dataset), 100. * test_acc))

# %%
def plot_loss(train_losses, valid_losses):
    plt.style.use('seaborn')
    fig, ax = plt.subplots(figsize=(8, 4.5))
    
    # find position of lowest validation loss
    minpos = valid_losses.index(min(valid_losses))

    train_losses = np.array(train_losses)
    valid_losses = np.array(valid_losses)

    ax.plot(train_losses, color='blue', label='Training loss')
    ax.plot(valid_losses, color='red', label='Validation loss')
    ax.set(title="Loss over epochs",
           xlabel='Epoch',
           ylabel='Loss')
    
    plt.axvline(minpos, linestyle='--', color='r',
                label='Early Stopping Checkpoint')
    ax.legend()

    # change the plot style to default
    plt.style.use('default')

# %%
def plot_acc(train_accuracies, validate_accuracies):
    plt.style.use('seaborn')
    fig, ax = plt.subplots(figsize=(8, 4.5))

    # find position of lowest validation loss
    maxpos = validate_accuracies.index(max(validate_accuracies))
    
    train_accuracies = np.array(train_accuracies)
    validate_accuracies = np.array(validate_accuracies)
    
    ax.plot(train_accuracies, color='blue', label='Training accuracy')
    ax.plot(validate_accuracies, color='red', label='Validation accuracy')
    ax.set(title="Accuracy over epochs",
           xlabel='Epoch',
           ylabel='Accuracy')
    
    plt.axvline(maxpos, linestyle='--', color='r',
                label='Early Stopping Checkpoint')
    ax.legend()

    # change the plot style to default
    plt.style.use('default')

# %%
def main():
    train_losses = []
    validate_losses = []
    train_accuracies = []
    validate_accuracies = []
    early_stopping = EarlyStopping(patience=patience, verbose=True)
    for epoch in range(epochs):
        train_loss, train_accuracy = train(epoch)
        train_losses.append(train_loss)
        train_accuracies.append(train_accuracy)
        validate_loss, validate_accuracy = validate()
        validate_losses.append(validate_loss)
        validate_accuracies.append(validate_accuracy)
        scheduler.step(validate_loss)
        early_stopping(val_loss=validate_loss, model=net)
        
        if early_stopping.early_stop:
            print("\nEarly stopping\n")
            break

    plot_loss(train_losses, validate_losses)
    plot_acc(train_accuracies, validate_accuracies)
    
    # load the last checkpoint with the best model
    net.load_state_dict(torch.load('checkpoint.pt'))

    test()

# %%
# %%time
if __name__ == '__main__':
    main()
# Out:
# Train Epoch: 1 [0/40000 (0%)]	Loss: 2.801937
# Train Epoch: 1 [6400/40000 (16%)]	Loss: 1.991796
# Train Epoch: 1 [12800/40000 (32%)]	Loss: 2.048577
# Train Epoch: 1 [19200/40000 (48%)]	Loss: 1.650561
# Train Epoch: 1 [25600/40000 (64%)]	Loss: 1.948284
# Train Epoch: 1 [32000/40000 (80%)]	Loss: 1.770286
# Train Epoch: 1 [38400/40000 (96%)]	Loss: 1.602555
# VAL set: Average loss: 0.028730, Accuracy: 3111.0/10000 (31.1%)
# Validation loss decreased (inf --> 0.028730).  Saving model ...
#
# Train Epoch: 2 [0/40000 (0%)]	Loss: 1.591432
# Train Epoch: 2 [6400/40000 (16%)]	Loss: 1.883901
# Train Epoch: 2 [12800/40000 (32%)]	Loss: 1.584485
# Train Epoch: 2 [19200/40000 (48%)]	Loss: 1.780308
# Train Epoch: 2 [25600/40000 (64%)]	Loss: 1.546984
# Train Epoch: 2 [32000/40000 (80%)]	Loss: 1.627000
# Train Epoch: 2 [38400/40000 (96%)]	Loss: 1.476895
# VAL set: Average loss: 0.026851, Accuracy: 4017.0/10000 (40.2%)
# Validation loss decreased (0.028730 --> 0.026851).  Saving model ...
#
# Train Epoch: 3 [0/40000 (0%)]	Loss: 1.490221
# Train Epoch: 3 [6400/40000 (16%)]	Loss: 1.467211
# Train Epoch: 3 [12800/40000 (32%)]	Loss: 1.533517
# Train Epoch: 3 [19200/40000 (48%)]	Loss: 1.557649
# Train Epoch: 3 [25600/40000 (64%)]	Loss: 1.619762
# Train Epoch: 3 [32000/40000 (80%)]	Loss: 1.382167
# Train Epoch: 3 [38400/40000 (96%)]	Loss: 1.409461
# VAL set: Average loss: 0.021548, Accuracy: 4985.0/10000 (49.9%)
# Validation loss decreased (0.026851 --> 0.021548).  Saving model ...
#
# Train Epoch: 4 [0/40000 (0%)]	Loss: 1.439819
# Train Epoch: 4 [6400/40000 (16%)]	Loss: 1.399004
# Train Epoch: 4 [12800/40000 (32%)]	Loss: 1.188373
# Train Epoch: 4 [19200/40000 (48%)]	Loss: 1.463100
# Train Epoch: 4 [25600/40000 (64%)]	Loss: 1.461022
# Train Epoch: 4 [32000/40000 (80%)]	Loss: 1.193322
# Train Epoch: 4 [38400/40000 (96%)]	Loss: 1.480492
# VAL set: Average loss: 0.027759, Accuracy: 4136.0/10000 (41.4%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 5 [0/40000 (0%)]	Loss: 1.330307
# Train Epoch: 5 [6400/40000 (16%)]	Loss: 1.356628
# Train Epoch: 5 [12800/40000 (32%)]	Loss: 1.326175
# Train Epoch: 5 [19200/40000 (48%)]	Loss: 1.518026
# Train Epoch: 5 [25600/40000 (64%)]	Loss: 1.204352
# Train Epoch: 5 [32000/40000 (80%)]	Loss: 1.434458
# Train Epoch: 5 [38400/40000 (96%)]	Loss: 1.229197
# VAL set: Average loss: 0.022100, Accuracy: 5058.0/10000 (50.6%)
# EarlyStopping counter: 2 out of 7
#
# Train Epoch: 6 [0/40000 (0%)]	Loss: 1.029809
# Train Epoch: 6 [6400/40000 (16%)]	Loss: 1.285704
# Train Epoch: 6 [12800/40000 (32%)]	Loss: 1.046688
# Train Epoch: 6 [19200/40000 (48%)]	Loss: 1.047159
# Train Epoch: 6 [25600/40000 (64%)]	Loss: 0.970567
# Train Epoch: 6 [32000/40000 (80%)]	Loss: 1.201594
# Train Epoch: 6 [38400/40000 (96%)]	Loss: 1.079771
# VAL set: Average loss: 0.019848, Accuracy: 5494.0/10000 (54.9%)
# Validation loss decreased (0.021548 --> 0.019848).  Saving model ...
#
# Train Epoch: 7 [0/40000 (0%)]	Loss: 1.208827
# Train Epoch: 7 [6400/40000 (16%)]	Loss: 1.339593
# Train Epoch: 7 [12800/40000 (32%)]	Loss: 1.173393
# Train Epoch: 7 [19200/40000 (48%)]	Loss: 0.949501
# Train Epoch: 7 [25600/40000 (64%)]	Loss: 0.918899
# Train Epoch: 7 [32000/40000 (80%)]	Loss: 1.239240
# Train Epoch: 7 [38400/40000 (96%)]	Loss: 1.147254
# VAL set: Average loss: 0.022234, Accuracy: 5114.0/10000 (51.1%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 8 [0/40000 (0%)]	Loss: 1.158486
# Train Epoch: 8 [6400/40000 (16%)]	Loss: 1.289516
# Train Epoch: 8 [12800/40000 (32%)]	Loss: 1.119417
# Train Epoch: 8 [19200/40000 (48%)]	Loss: 0.641989
# Train Epoch: 8 [25600/40000 (64%)]	Loss: 1.169085
# Train Epoch: 8 [32000/40000 (80%)]	Loss: 0.834478
# Train Epoch: 8 [38400/40000 (96%)]	Loss: 0.901208
# VAL set: Average loss: 0.016613, Accuracy: 6305.0/10000 (63.0%)
# Validation loss decreased (0.019848 --> 0.016613).  Saving model ...
#
# Train Epoch: 9 [0/40000 (0%)]	Loss: 1.066156
# Train Epoch: 9 [6400/40000 (16%)]	Loss: 1.061766
# Train Epoch: 9 [12800/40000 (32%)]	Loss: 1.127821
# Train Epoch: 9 [19200/40000 (48%)]	Loss: 1.136658
# Train Epoch: 9 [25600/40000 (64%)]	Loss: 1.204764
# Train Epoch: 9 [32000/40000 (80%)]	Loss: 1.111868
# Train Epoch: 9 [38400/40000 (96%)]	Loss: 0.836235
# VAL set: Average loss: 0.021125, Accuracy: 5455.0/10000 (54.5%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 10 [0/40000 (0%)]	Loss: 0.690996
# Train Epoch: 10 [6400/40000 (16%)]	Loss: 0.970000
# Train Epoch: 10 [12800/40000 (32%)]	Loss: 1.171093
# Train Epoch: 10 [19200/40000 (48%)]	Loss: 1.149795
# Train Epoch: 10 [25600/40000 (64%)]	Loss: 0.954324
# Train Epoch: 10 [32000/40000 (80%)]	Loss: 1.290969
# Train Epoch: 10 [38400/40000 (96%)]	Loss: 1.199109
# VAL set: Average loss: 0.017238, Accuracy: 6180.0/10000 (61.8%)
# EarlyStopping counter: 2 out of 7
#
# Train Epoch: 11 [0/40000 (0%)]	Loss: 1.229024
# Train Epoch: 11 [6400/40000 (16%)]	Loss: 1.100924
# Train Epoch: 11 [12800/40000 (32%)]	Loss: 1.062893
# Train Epoch: 11 [19200/40000 (48%)]	Loss: 1.113236
# Train Epoch: 11 [25600/40000 (64%)]	Loss: 0.752517
# Train Epoch: 11 [32000/40000 (80%)]	Loss: 1.116302
# Train Epoch: 11 [38400/40000 (96%)]	Loss: 1.093357
# VAL set: Average loss: 0.016936, Accuracy: 6300.0/10000 (63.0%)
# EarlyStopping counter: 3 out of 7
#
# Train Epoch: 12 [0/40000 (0%)]	Loss: 1.047292
# Train Epoch: 12 [6400/40000 (16%)]	Loss: 0.896774
# Train Epoch: 12 [12800/40000 (32%)]	Loss: 0.940684
# Train Epoch: 12 [19200/40000 (48%)]	Loss: 0.966120
# Train Epoch: 12 [25600/40000 (64%)]	Loss: 0.805073
# Train Epoch: 12 [32000/40000 (80%)]	Loss: 1.174246
# Train Epoch: 12 [38400/40000 (96%)]	Loss: 0.974409
# VAL set: Average loss: 0.016548, Accuracy: 6442.0/10000 (64.4%)
# Validation loss decreased (0.016613 --> 0.016548).  Saving model ...
#
# Train Epoch: 13 [0/40000 (0%)]	Loss: 1.154548
# Train Epoch: 13 [6400/40000 (16%)]	Loss: 0.926955
# Train Epoch: 13 [12800/40000 (32%)]	Loss: 0.820305
# Train Epoch: 13 [19200/40000 (48%)]	Loss: 1.067097
# Train Epoch: 13 [25600/40000 (64%)]	Loss: 0.982506
# Train Epoch: 13 [32000/40000 (80%)]	Loss: 0.804516
# Train Epoch: 13 [38400/40000 (96%)]	Loss: 0.984204
# VAL set: Average loss: 0.015444, Accuracy: 6541.0/10000 (65.4%)
# Validation loss decreased (0.016548 --> 0.015444).  Saving model ...
#
# Train Epoch: 14 [0/40000 (0%)]	Loss: 0.614202
# Train Epoch: 14 [6400/40000 (16%)]	Loss: 0.841181
# Train Epoch: 14 [12800/40000 (32%)]	Loss: 0.776314
# Train Epoch: 14 [19200/40000 (48%)]	Loss: 0.849468
# Train Epoch: 14 [25600/40000 (64%)]	Loss: 1.351335
# Train Epoch: 14 [32000/40000 (80%)]	Loss: 0.758490
# Train Epoch: 14 [38400/40000 (96%)]	Loss: 0.990503
# VAL set: Average loss: 0.014529, Accuracy: 6763.0/10000 (67.6%)
# Validation loss decreased (0.015444 --> 0.014529).  Saving model ...
#
# Train Epoch: 15 [0/40000 (0%)]	Loss: 0.954767
# Train Epoch: 15 [6400/40000 (16%)]	Loss: 0.980930
# Train Epoch: 15 [12800/40000 (32%)]	Loss: 0.825307
# Train Epoch: 15 [19200/40000 (48%)]	Loss: 0.643424
# Train Epoch: 15 [25600/40000 (64%)]	Loss: 0.586951
# Train Epoch: 15 [32000/40000 (80%)]	Loss: 0.738205
# Train Epoch: 15 [38400/40000 (96%)]	Loss: 0.739510
# VAL set: Average loss: 0.015370, Accuracy: 6697.0/10000 (67.0%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 16 [0/40000 (0%)]	Loss: 0.882769
# Train Epoch: 16 [6400/40000 (16%)]	Loss: 0.605952
# Train Epoch: 16 [12800/40000 (32%)]	Loss: 0.920338
# Train Epoch: 16 [19200/40000 (48%)]	Loss: 0.770678
# Train Epoch: 16 [25600/40000 (64%)]	Loss: 0.808876
# Train Epoch: 16 [32000/40000 (80%)]	Loss: 0.781958
# Train Epoch: 16 [38400/40000 (96%)]	Loss: 0.770236
# VAL set: Average loss: 0.015921, Accuracy: 6515.0/10000 (65.1%)
# EarlyStopping counter: 2 out of 7
#
# Train Epoch: 17 [0/40000 (0%)]	Loss: 1.108824
# Train Epoch: 17 [6400/40000 (16%)]	Loss: 0.754557
# Train Epoch: 17 [12800/40000 (32%)]	Loss: 0.705179
# Train Epoch: 17 [19200/40000 (48%)]	Loss: 0.701471
# Train Epoch: 17 [25600/40000 (64%)]	Loss: 0.869975
# Train Epoch: 17 [32000/40000 (80%)]	Loss: 0.930900
# Train Epoch: 17 [38400/40000 (96%)]	Loss: 0.869669
# VAL set: Average loss: 0.013545, Accuracy: 7008.0/10000 (70.1%)
# Validation loss decreased (0.014529 --> 0.013545).  Saving model ...
#
# Train Epoch: 18 [0/40000 (0%)]	Loss: 0.948121
# Train Epoch: 18 [6400/40000 (16%)]	Loss: 0.634955
# Train Epoch: 18 [12800/40000 (32%)]	Loss: 0.723809
# Train Epoch: 18 [19200/40000 (48%)]	Loss: 0.945911
# Train Epoch: 18 [25600/40000 (64%)]	Loss: 0.824424
# Train Epoch: 18 [32000/40000 (80%)]	Loss: 1.097613
# Train Epoch: 18 [38400/40000 (96%)]	Loss: 0.772396
# VAL set: Average loss: 0.015358, Accuracy: 6667.0/10000 (66.7%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 19 [0/40000 (0%)]	Loss: 0.959318
# Train Epoch: 19 [6400/40000 (16%)]	Loss: 0.806379
# Train Epoch: 19 [12800/40000 (32%)]	Loss: 0.781339
# Train Epoch: 19 [19200/40000 (48%)]	Loss: 0.867275
# Train Epoch: 19 [25600/40000 (64%)]	Loss: 0.697592
# Train Epoch: 19 [32000/40000 (80%)]	Loss: 0.749721
# Train Epoch: 19 [38400/40000 (96%)]	Loss: 0.923669
# VAL set: Average loss: 0.012913, Accuracy: 7107.0/10000 (71.1%)
# Validation loss decreased (0.013545 --> 0.012913).  Saving model ...
#
# Train Epoch: 20 [0/40000 (0%)]	Loss: 0.681212
# Train Epoch: 20 [6400/40000 (16%)]	Loss: 0.900607
# Train Epoch: 20 [12800/40000 (32%)]	Loss: 0.876605
# Train Epoch: 20 [19200/40000 (48%)]	Loss: 0.791544
# Train Epoch: 20 [25600/40000 (64%)]	Loss: 0.654369
# Train Epoch: 20 [32000/40000 (80%)]	Loss: 0.669702
# Train Epoch: 20 [38400/40000 (96%)]	Loss: 0.626090
# VAL set: Average loss: 0.015124, Accuracy: 6705.0/10000 (67.0%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 21 [0/40000 (0%)]	Loss: 0.797542
# Train Epoch: 21 [6400/40000 (16%)]	Loss: 0.755191
# Train Epoch: 21 [12800/40000 (32%)]	Loss: 0.746526
# Train Epoch: 21 [19200/40000 (48%)]	Loss: 0.707565
# Train Epoch: 21 [25600/40000 (64%)]	Loss: 0.666742
# Train Epoch: 21 [32000/40000 (80%)]	Loss: 0.642200
# Train Epoch: 21 [38400/40000 (96%)]	Loss: 0.830173
# VAL set: Average loss: 0.012637, Accuracy: 7237.0/10000 (72.4%)
# Validation loss decreased (0.012913 --> 0.012637).  Saving model ...
#
# Train Epoch: 22 [0/40000 (0%)]	Loss: 0.842192
# Train Epoch: 22 [6400/40000 (16%)]	Loss: 0.668602
# Train Epoch: 22 [12800/40000 (32%)]	Loss: 0.806647
# Train Epoch: 22 [19200/40000 (48%)]	Loss: 0.866428
# Train Epoch: 22 [25600/40000 (64%)]	Loss: 0.828338
# Train Epoch: 22 [32000/40000 (80%)]	Loss: 0.798317
# Train Epoch: 22 [38400/40000 (96%)]	Loss: 0.612842
# VAL set: Average loss: 0.011976, Accuracy: 7387.0/10000 (73.9%)
# Validation loss decreased (0.012637 --> 0.011976).  Saving model ...
#
# Train Epoch: 23 [0/40000 (0%)]	Loss: 0.632202
# Train Epoch: 23 [6400/40000 (16%)]	Loss: 0.795478
# Train Epoch: 23 [12800/40000 (32%)]	Loss: 0.695041
# Train Epoch: 23 [19200/40000 (48%)]	Loss: 0.691914
# Train Epoch: 23 [25600/40000 (64%)]	Loss: 0.969686
# Train Epoch: 23 [32000/40000 (80%)]	Loss: 0.693184
# Train Epoch: 23 [38400/40000 (96%)]	Loss: 0.652393
# VAL set: Average loss: 0.014842, Accuracy: 6841.0/10000 (68.4%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 24 [0/40000 (0%)]	Loss: 0.616134
# Train Epoch: 24 [6400/40000 (16%)]	Loss: 0.840145
# Train Epoch: 24 [12800/40000 (32%)]	Loss: 0.779644
# Train Epoch: 24 [19200/40000 (48%)]	Loss: 0.661377
# Train Epoch: 24 [25600/40000 (64%)]	Loss: 0.779346
# Train Epoch: 24 [32000/40000 (80%)]	Loss: 0.553534
# Train Epoch: 24 [38400/40000 (96%)]	Loss: 0.830640
# VAL set: Average loss: 0.013311, Accuracy: 7143.0/10000 (71.4%)
# EarlyStopping counter: 2 out of 7
#
# Train Epoch: 25 [0/40000 (0%)]	Loss: 0.650222
# Train Epoch: 25 [6400/40000 (16%)]	Loss: 0.522807
# Train Epoch: 25 [12800/40000 (32%)]	Loss: 0.747248
# Train Epoch: 25 [19200/40000 (48%)]	Loss: 0.750965
# Train Epoch: 25 [25600/40000 (64%)]	Loss: 0.673427
# Train Epoch: 25 [32000/40000 (80%)]	Loss: 0.561575
# Train Epoch: 25 [38400/40000 (96%)]	Loss: 0.543179
# VAL set: Average loss: 0.011901, Accuracy: 7408.0/10000 (74.1%)
# Validation loss decreased (0.011976 --> 0.011901).  Saving model ...
#
# Train Epoch: 26 [0/40000 (0%)]	Loss: 0.505133
# Train Epoch: 26 [6400/40000 (16%)]	Loss: 0.461689
# Train Epoch: 26 [12800/40000 (32%)]	Loss: 0.742092
# Train Epoch: 26 [19200/40000 (48%)]	Loss: 0.909334
# Train Epoch: 26 [25600/40000 (64%)]	Loss: 0.770853
# Train Epoch: 26 [32000/40000 (80%)]	Loss: 0.519806
# Train Epoch: 26 [38400/40000 (96%)]	Loss: 0.627310
# VAL set: Average loss: 0.012478, Accuracy: 7324.0/10000 (73.2%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 27 [0/40000 (0%)]	Loss: 0.449861
# Train Epoch: 27 [6400/40000 (16%)]	Loss: 0.664807
# Train Epoch: 27 [12800/40000 (32%)]	Loss: 0.725365
# Train Epoch: 27 [19200/40000 (48%)]	Loss: 0.853674
# Train Epoch: 27 [25600/40000 (64%)]	Loss: 0.585542
# Train Epoch: 27 [32000/40000 (80%)]	Loss: 0.538391
# Train Epoch: 27 [38400/40000 (96%)]	Loss: 0.816863
# VAL set: Average loss: 0.011711, Accuracy: 7487.0/10000 (74.9%)
# Validation loss decreased (0.011901 --> 0.011711).  Saving model ...
#
# Train Epoch: 28 [0/40000 (0%)]	Loss: 0.600038
# Train Epoch: 28 [6400/40000 (16%)]	Loss: 0.732673
# Train Epoch: 28 [12800/40000 (32%)]	Loss: 0.855195
# Train Epoch: 28 [19200/40000 (48%)]	Loss: 0.811883
# Train Epoch: 28 [25600/40000 (64%)]	Loss: 0.577151
# Train Epoch: 28 [32000/40000 (80%)]	Loss: 0.558088
# Train Epoch: 28 [38400/40000 (96%)]	Loss: 0.637776
# VAL set: Average loss: 0.011947, Accuracy: 7363.0/10000 (73.6%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 29 [0/40000 (0%)]	Loss: 0.610563
# Train Epoch: 29 [6400/40000 (16%)]	Loss: 0.424493
# Train Epoch: 29 [12800/40000 (32%)]	Loss: 0.648575
# Train Epoch: 29 [19200/40000 (48%)]	Loss: 0.607410
# Train Epoch: 29 [25600/40000 (64%)]	Loss: 0.677450
# Train Epoch: 29 [32000/40000 (80%)]	Loss: 0.631672
# Train Epoch: 29 [38400/40000 (96%)]	Loss: 0.470960
# VAL set: Average loss: 0.011023, Accuracy: 7580.0/10000 (75.8%)
# Validation loss decreased (0.011711 --> 0.011023).  Saving model ...
#
# Train Epoch: 30 [0/40000 (0%)]	Loss: 0.587637
# Train Epoch: 30 [6400/40000 (16%)]	Loss: 0.445537
# Train Epoch: 30 [12800/40000 (32%)]	Loss: 0.611840
# Train Epoch: 30 [19200/40000 (48%)]	Loss: 0.680173
# Train Epoch: 30 [25600/40000 (64%)]	Loss: 0.569785
# Train Epoch: 30 [32000/40000 (80%)]	Loss: 0.568875
# Train Epoch: 30 [38400/40000 (96%)]	Loss: 0.651169
# VAL set: Average loss: 0.011549, Accuracy: 7466.0/10000 (74.7%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 31 [0/40000 (0%)]	Loss: 0.637504
# Train Epoch: 31 [6400/40000 (16%)]	Loss: 0.658292
# Train Epoch: 31 [12800/40000 (32%)]	Loss: 0.620767
# Train Epoch: 31 [19200/40000 (48%)]	Loss: 0.782939
# Train Epoch: 31 [25600/40000 (64%)]	Loss: 0.885901
# Train Epoch: 31 [32000/40000 (80%)]	Loss: 0.511320
# Train Epoch: 31 [38400/40000 (96%)]	Loss: 0.430633
# VAL set: Average loss: 0.011206, Accuracy: 7559.0/10000 (75.6%)
# EarlyStopping counter: 2 out of 7
#
# Train Epoch: 32 [0/40000 (0%)]	Loss: 0.506091
# Train Epoch: 32 [6400/40000 (16%)]	Loss: 0.461646
# Train Epoch: 32 [12800/40000 (32%)]	Loss: 0.704413
# Train Epoch: 32 [19200/40000 (48%)]	Loss: 0.805020
# Train Epoch: 32 [25600/40000 (64%)]	Loss: 0.617930
# Train Epoch: 32 [32000/40000 (80%)]	Loss: 0.722942
# Train Epoch: 32 [38400/40000 (96%)]	Loss: 0.438762
# VAL set: Average loss: 0.011505, Accuracy: 7487.0/10000 (74.9%)
# EarlyStopping counter: 3 out of 7
#
# Train Epoch: 33 [0/40000 (0%)]	Loss: 0.754737
# Train Epoch: 33 [6400/40000 (16%)]	Loss: 0.597781
# Train Epoch: 33 [12800/40000 (32%)]	Loss: 0.466693
# Train Epoch: 33 [19200/40000 (48%)]	Loss: 0.639192
# Train Epoch: 33 [25600/40000 (64%)]	Loss: 0.694260
# Train Epoch: 33 [32000/40000 (80%)]	Loss: 0.676595
# Train Epoch: 33 [38400/40000 (96%)]	Loss: 0.737666
# VAL set: Average loss: 0.011210, Accuracy: 7574.0/10000 (75.7%)
# EarlyStopping counter: 4 out of 7
#
# Train Epoch: 34 [0/40000 (0%)]	Loss: 0.442962
# Train Epoch: 34 [6400/40000 (16%)]	Loss: 0.570758
# Train Epoch: 34 [12800/40000 (32%)]	Loss: 0.822362
# Train Epoch: 34 [19200/40000 (48%)]	Loss: 0.717336
# Train Epoch: 34 [25600/40000 (64%)]	Loss: 0.760805
# Train Epoch: 34 [32000/40000 (80%)]	Loss: 0.329391
# Train Epoch: 34 [38400/40000 (96%)]	Loss: 0.349300
# VAL set: Average loss: 0.009512, Accuracy: 7897.0/10000 (79.0%)
# Validation loss decreased (0.011023 --> 0.009512).  Saving model ...
#
# Train Epoch: 35 [0/40000 (0%)]	Loss: 0.484738
# Train Epoch: 35 [6400/40000 (16%)]	Loss: 0.551495
# Train Epoch: 35 [12800/40000 (32%)]	Loss: 0.667412
# Train Epoch: 35 [19200/40000 (48%)]	Loss: 0.565597
# Train Epoch: 35 [25600/40000 (64%)]	Loss: 0.462500
# Train Epoch: 35 [32000/40000 (80%)]	Loss: 0.638495
# Train Epoch: 35 [38400/40000 (96%)]	Loss: 0.623253
# VAL set: Average loss: 0.009547, Accuracy: 7884.0/10000 (78.8%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 36 [0/40000 (0%)]	Loss: 0.379751
# Train Epoch: 36 [6400/40000 (16%)]	Loss: 0.370131
# Train Epoch: 36 [12800/40000 (32%)]	Loss: 0.516250
# Train Epoch: 36 [19200/40000 (48%)]	Loss: 0.399787
# Train Epoch: 36 [25600/40000 (64%)]	Loss: 0.468352
# Train Epoch: 36 [32000/40000 (80%)]	Loss: 0.315868
# Train Epoch: 36 [38400/40000 (96%)]	Loss: 0.420702
# VAL set: Average loss: 0.009665, Accuracy: 7824.0/10000 (78.2%)
# EarlyStopping counter: 2 out of 7
#
# Train Epoch: 37 [0/40000 (0%)]	Loss: 0.513339
# Train Epoch: 37 [6400/40000 (16%)]	Loss: 0.485308
# Train Epoch: 37 [12800/40000 (32%)]	Loss: 0.264173
# Train Epoch: 37 [19200/40000 (48%)]	Loss: 0.573298
# Train Epoch: 37 [25600/40000 (64%)]	Loss: 0.474741
# Train Epoch: 37 [32000/40000 (80%)]	Loss: 0.426192
# Train Epoch: 37 [38400/40000 (96%)]	Loss: 0.426017
# VAL set: Average loss: 0.009638, Accuracy: 7897.0/10000 (79.0%)
# EarlyStopping counter: 3 out of 7
#
# Train Epoch: 38 [0/40000 (0%)]	Loss: 0.698650
# Train Epoch: 38 [6400/40000 (16%)]	Loss: 0.429596
# Train Epoch: 38 [12800/40000 (32%)]	Loss: 0.636941
# Train Epoch: 38 [19200/40000 (48%)]	Loss: 0.496210
# Train Epoch: 38 [25600/40000 (64%)]	Loss: 0.552434
# Train Epoch: 38 [32000/40000 (80%)]	Loss: 0.426735
# Train Epoch: 38 [38400/40000 (96%)]	Loss: 0.432800
# VAL set: Average loss: 0.009412, Accuracy: 7935.0/10000 (79.3%)
# Validation loss decreased (0.009512 --> 0.009412).  Saving model ...
#
# Train Epoch: 39 [0/40000 (0%)]	Loss: 0.396453
# Train Epoch: 39 [6400/40000 (16%)]	Loss: 0.554483
# Train Epoch: 39 [12800/40000 (32%)]	Loss: 0.610851
# Train Epoch: 39 [19200/40000 (48%)]	Loss: 0.373461
# Train Epoch: 39 [25600/40000 (64%)]	Loss: 0.538502
# Train Epoch: 39 [32000/40000 (80%)]	Loss: 0.596569
# Train Epoch: 39 [38400/40000 (96%)]	Loss: 0.569676
# VAL set: Average loss: 0.009497, Accuracy: 7907.0/10000 (79.1%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 40 [0/40000 (0%)]	Loss: 0.268110
# Train Epoch: 40 [6400/40000 (16%)]	Loss: 0.414240
# Train Epoch: 40 [12800/40000 (32%)]	Loss: 0.328170
# Train Epoch: 40 [19200/40000 (48%)]	Loss: 0.556398
# Train Epoch: 40 [25600/40000 (64%)]	Loss: 0.501002
# Train Epoch: 40 [32000/40000 (80%)]	Loss: 0.420225
# Train Epoch: 40 [38400/40000 (96%)]	Loss: 0.508192
# VAL set: Average loss: 0.009471, Accuracy: 7883.0/10000 (78.8%)
# EarlyStopping counter: 2 out of 7
#
# Train Epoch: 41 [0/40000 (0%)]	Loss: 0.779155
# Train Epoch: 41 [6400/40000 (16%)]	Loss: 0.522508
# Train Epoch: 41 [12800/40000 (32%)]	Loss: 0.624916
# Train Epoch: 41 [19200/40000 (48%)]	Loss: 0.475814
# Train Epoch: 41 [25600/40000 (64%)]	Loss: 0.623137
# Train Epoch: 41 [32000/40000 (80%)]	Loss: 0.438432
# Train Epoch: 41 [38400/40000 (96%)]	Loss: 0.476982
# VAL set: Average loss: 0.009619, Accuracy: 7898.0/10000 (79.0%)
# EarlyStopping counter: 3 out of 7
#
# Train Epoch: 42 [0/40000 (0%)]	Loss: 0.579549
# Train Epoch: 42 [6400/40000 (16%)]	Loss: 0.433644
# Train Epoch: 42 [12800/40000 (32%)]	Loss: 0.525317
# Train Epoch: 42 [19200/40000 (48%)]	Loss: 0.353541
# Train Epoch: 42 [25600/40000 (64%)]	Loss: 0.634701
# Train Epoch: 42 [32000/40000 (80%)]	Loss: 0.282521
# Train Epoch: 42 [38400/40000 (96%)]	Loss: 0.470403
# VAL set: Average loss: 0.009755, Accuracy: 7846.0/10000 (78.5%)
# EarlyStopping counter: 4 out of 7
#
# Train Epoch: 43 [0/40000 (0%)]	Loss: 0.430307
# Train Epoch: 43 [6400/40000 (16%)]	Loss: 0.334525
# Train Epoch: 43 [12800/40000 (32%)]	Loss: 0.356481
# Train Epoch: 43 [19200/40000 (48%)]	Loss: 0.305869
# Train Epoch: 43 [25600/40000 (64%)]	Loss: 0.544324
# Train Epoch: 43 [32000/40000 (80%)]	Loss: 0.643236
# Train Epoch: 43 [38400/40000 (96%)]	Loss: 0.368392
# VAL set: Average loss: 0.009085, Accuracy: 7979.0/10000 (79.8%)
# Validation loss decreased (0.009412 --> 0.009085).  Saving model ...
#
# Train Epoch: 44 [0/40000 (0%)]	Loss: 0.394361
# Train Epoch: 44 [6400/40000 (16%)]	Loss: 0.536201
# Train Epoch: 44 [12800/40000 (32%)]	Loss: 0.634431
# Train Epoch: 44 [19200/40000 (48%)]	Loss: 0.387648
# Train Epoch: 44 [25600/40000 (64%)]	Loss: 0.357905
# Train Epoch: 44 [32000/40000 (80%)]	Loss: 0.447900
# Train Epoch: 44 [38400/40000 (96%)]	Loss: 0.337472
# VAL set: Average loss: 0.009086, Accuracy: 8002.0/10000 (80.0%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 45 [0/40000 (0%)]	Loss: 0.390364
# Train Epoch: 45 [6400/40000 (16%)]	Loss: 0.316601
# Train Epoch: 45 [12800/40000 (32%)]	Loss: 0.472432
# Train Epoch: 45 [19200/40000 (48%)]	Loss: 0.668719
# Train Epoch: 45 [25600/40000 (64%)]	Loss: 0.490050
# Train Epoch: 45 [32000/40000 (80%)]	Loss: 0.621453
# Train Epoch: 45 [38400/40000 (96%)]	Loss: 0.416109
# VAL set: Average loss: 0.009192, Accuracy: 7941.0/10000 (79.4%)
# EarlyStopping counter: 2 out of 7
#
# Train Epoch: 46 [0/40000 (0%)]	Loss: 0.426867
# Train Epoch: 46 [6400/40000 (16%)]	Loss: 0.302180
# Train Epoch: 46 [12800/40000 (32%)]	Loss: 0.493967
# Train Epoch: 46 [19200/40000 (48%)]	Loss: 0.578599
# Train Epoch: 46 [25600/40000 (64%)]	Loss: 0.488912
# Train Epoch: 46 [32000/40000 (80%)]	Loss: 0.507575
# Train Epoch: 46 [38400/40000 (96%)]	Loss: 0.388400
# VAL set: Average loss: 0.009182, Accuracy: 7955.0/10000 (79.5%)
# EarlyStopping counter: 3 out of 7
#
# Train Epoch: 47 [0/40000 (0%)]	Loss: 0.423927
# Train Epoch: 47 [6400/40000 (16%)]	Loss: 0.569561
# Train Epoch: 47 [12800/40000 (32%)]	Loss: 0.475059
# Train Epoch: 47 [19200/40000 (48%)]	Loss: 0.383183
# Train Epoch: 47 [25600/40000 (64%)]	Loss: 0.374845
# Train Epoch: 47 [32000/40000 (80%)]	Loss: 0.408238
# Train Epoch: 47 [38400/40000 (96%)]	Loss: 0.342927
# VAL set: Average loss: 0.009231, Accuracy: 7975.0/10000 (79.8%)
# EarlyStopping counter: 4 out of 7
#
# Train Epoch: 48 [0/40000 (0%)]	Loss: 0.414466
# Train Epoch: 48 [6400/40000 (16%)]	Loss: 0.457313
# Train Epoch: 48 [12800/40000 (32%)]	Loss: 0.383054
# Train Epoch: 48 [19200/40000 (48%)]	Loss: 0.410253
# Train Epoch: 48 [25600/40000 (64%)]	Loss: 0.431478
# Train Epoch: 48 [32000/40000 (80%)]	Loss: 0.319610
# Train Epoch: 48 [38400/40000 (96%)]	Loss: 0.606625
# VAL set: Average loss: 0.009184, Accuracy: 8002.0/10000 (80.0%)
# EarlyStopping counter: 5 out of 7
#
# Train Epoch: 49 [0/40000 (0%)]	Loss: 0.647276
# Train Epoch: 49 [6400/40000 (16%)]	Loss: 0.287694
# Train Epoch: 49 [12800/40000 (32%)]	Loss: 0.596177
# Train Epoch: 49 [19200/40000 (48%)]	Loss: 0.396438
# Train Epoch: 49 [25600/40000 (64%)]	Loss: 0.633406
# Train Epoch: 49 [32000/40000 (80%)]	Loss: 0.482689
# Train Epoch: 49 [38400/40000 (96%)]	Loss: 0.462287
# VAL set: Average loss: 0.009101, Accuracy: 8032.0/10000 (80.3%)
# EarlyStopping counter: 6 out of 7
#
# Train Epoch: 50 [0/40000 (0%)]	Loss: 0.324895
# Train Epoch: 50 [6400/40000 (16%)]	Loss: 0.395357
# Train Epoch: 50 [12800/40000 (32%)]	Loss: 0.357639
# Train Epoch: 50 [19200/40000 (48%)]	Loss: 0.243520
# Train Epoch: 50 [25600/40000 (64%)]	Loss: 0.398300
# Train Epoch: 50 [32000/40000 (80%)]	Loss: 0.453358
# Train Epoch: 50 [38400/40000 (96%)]	Loss: 0.571284
# VAL set: Average loss: 0.009015, Accuracy: 8032.0/10000 (80.3%)
# Validation loss decreased (0.009085 --> 0.009015).  Saving model ...
#
# Train Epoch: 51 [0/40000 (0%)]	Loss: 0.427863
# Train Epoch: 51 [6400/40000 (16%)]	Loss: 0.253167
# Train Epoch: 51 [12800/40000 (32%)]	Loss: 0.548943
# Train Epoch: 51 [19200/40000 (48%)]	Loss: 0.285132
# Train Epoch: 51 [25600/40000 (64%)]	Loss: 0.253531
# Train Epoch: 51 [32000/40000 (80%)]	Loss: 0.423790
# Train Epoch: 51 [38400/40000 (96%)]	Loss: 0.468820
# VAL set: Average loss: 0.009142, Accuracy: 7986.0/10000 (79.9%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 52 [0/40000 (0%)]	Loss: 0.328076
# Train Epoch: 52 [6400/40000 (16%)]	Loss: 0.436851
# Train Epoch: 52 [12800/40000 (32%)]	Loss: 0.470143
# Train Epoch: 52 [19200/40000 (48%)]	Loss: 0.520875
# Train Epoch: 52 [25600/40000 (64%)]	Loss: 0.508559
# Train Epoch: 52 [32000/40000 (80%)]	Loss: 0.289220
# Train Epoch: 52 [38400/40000 (96%)]	Loss: 0.642432
# VAL set: Average loss: 0.008956, Accuracy: 8014.0/10000 (80.1%)
# Validation loss decreased (0.009015 --> 0.008956).  Saving model ...
#
# Train Epoch: 53 [0/40000 (0%)]	Loss: 0.627117
# Train Epoch: 53 [6400/40000 (16%)]	Loss: 0.541200
# Train Epoch: 53 [12800/40000 (32%)]	Loss: 0.299150
# Train Epoch: 53 [19200/40000 (48%)]	Loss: 0.472854
# Train Epoch: 53 [25600/40000 (64%)]	Loss: 0.377632
# Train Epoch: 53 [32000/40000 (80%)]	Loss: 0.404702
# Train Epoch: 53 [38400/40000 (96%)]	Loss: 0.361919
# VAL set: Average loss: 0.009066, Accuracy: 8012.0/10000 (80.1%)
# EarlyStopping counter: 1 out of 7
#
# Train Epoch: 54 [0/40000 (0%)]	Loss: 0.499365
# Train Epoch: 54 [6400/40000 (16%)]	Loss: 0.418670
# Train Epoch: 54 [12800/40000 (32%)]	Loss: 0.655026
# Train Epoch: 54 [19200/40000 (48%)]	Loss: 0.559396
# Train Epoch: 54 [25600/40000 (64%)]	Loss: 0.547064
# Train Epoch: 54 [32000/40000 (80%)]	Loss: 0.386087
# Train Epoch: 54 [38400/40000 (96%)]	Loss: 0.438284
# VAL set: Average loss: 0.009095, Accuracy: 8007.0/10000 (80.1%)
# EarlyStopping counter: 2 out of 7
#
# Train Epoch: 55 [0/40000 (0%)]	Loss: 0.251106
# Train Epoch: 55 [6400/40000 (16%)]	Loss: 0.383035
# Train Epoch: 55 [12800/40000 (32%)]	Loss: 0.406798
# Train Epoch: 55 [19200/40000 (48%)]	Loss: 0.288062
# Train Epoch: 55 [25600/40000 (64%)]	Loss: 0.411101
# Train Epoch: 55 [32000/40000 (80%)]	Loss: 0.421506
# Train Epoch: 55 [38400/40000 (96%)]	Loss: 0.494195
# VAL set: Average loss: 0.009080, Accuracy: 8017.0/10000 (80.2%)
# EarlyStopping counter: 3 out of 7
#
# Train Epoch: 56 [0/40000 (0%)]	Loss: 0.691800
# Train Epoch: 56 [6400/40000 (16%)]	Loss: 0.292496
# Train Epoch: 56 [12800/40000 (32%)]	Loss: 0.325670
# Train Epoch: 56 [19200/40000 (48%)]	Loss: 0.401502
# Train Epoch: 56 [25600/40000 (64%)]	Loss: 0.554813
# Train Epoch: 56 [32000/40000 (80%)]	Loss: 0.436980
# Train Epoch: 56 [38400/40000 (96%)]	Loss: 0.264827
# VAL set: Average loss: 0.009136, Accuracy: 7973.0/10000 (79.7%)
# EarlyStopping counter: 4 out of 7
#
# Train Epoch: 57 [0/40000 (0%)]	Loss: 0.331307
# Train Epoch: 57 [6400/40000 (16%)]	Loss: 0.260073
# Train Epoch: 57 [12800/40000 (32%)]	Loss: 0.418978
# Train Epoch: 57 [19200/40000 (48%)]	Loss: 0.411757
# Train Epoch: 57 [25600/40000 (64%)]	Loss: 0.360899
# Train Epoch: 57 [32000/40000 (80%)]	Loss: 0.515129
# Train Epoch: 57 [38400/40000 (96%)]	Loss: 0.354460
# VAL set: Average loss: 0.009051, Accuracy: 8017.0/10000 (80.2%)
# EarlyStopping counter: 5 out of 7
#
# Train Epoch: 58 [0/40000 (0%)]	Loss: 0.253380
# Train Epoch: 58 [6400/40000 (16%)]	Loss: 0.510966
# Train Epoch: 58 [12800/40000 (32%)]	Loss: 0.402955
# Train Epoch: 58 [19200/40000 (48%)]	Loss: 0.628023
# Train Epoch: 58 [25600/40000 (64%)]	Loss: 0.568341
# Train Epoch: 58 [32000/40000 (80%)]	Loss: 0.360720
# Train Epoch: 58 [38400/40000 (96%)]	Loss: 0.372459
# VAL set: Average loss: 0.009030, Accuracy: 8023.0/10000 (80.2%)
# EarlyStopping counter: 6 out of 7
#
# Train Epoch: 59 [0/40000 (0%)]	Loss: 0.398386
# Train Epoch: 59 [6400/40000 (16%)]	Loss: 0.419972
# Train Epoch: 59 [12800/40000 (32%)]	Loss: 0.362542
# Train Epoch: 59 [19200/40000 (48%)]	Loss: 0.682953
# Train Epoch: 59 [25600/40000 (64%)]	Loss: 0.436779
# Train Epoch: 59 [32000/40000 (80%)]	Loss: 0.317976
# Train Epoch: 59 [38400/40000 (96%)]	Loss: 0.499358
# VAL set: Average loss: 0.009248, Accuracy: 7939.0/10000 (79.4%)
# EarlyStopping counter: 7 out of 7
#
#
# Early stopping
#
#
# Test set: Average loss: 0.009030, Accuracy: 8004.0/10000 (80%)
#
# CPU times: user 3h 58min 19s, sys: 4h 20min 23s, total: 8h 18min 43s
# Wall time: 1h 24min 19s

# %%
CIFAR_dict = {0: 'airplane',
              1: 'automobile',
              2: 'brid',
              3: 'cat',
              4: 'deer',
              5: 'dog',
              6: 'frog',
              7: 'horse',
              8: 'ship',
              9: 'truck'}

ROW_IMG = 10
N_ROWS = 5

fig = plt.figure()
for index in range(1, ROW_IMG * N_ROWS + 1):
    plt.subplot(N_ROWS, ROW_IMG, index)
    plt.axis('off')
    plt.imshow(test_db.data[index])

    with torch.no_grad():
        net.eval()
        logits = net(test_db[index][0].unsqueeze(0).to(DEVICE))
        probs = F.softmax(logits, dim=1)

    title = f'{CIFAR_dict[int(torch.argmax(probs))]} ({torch.max(probs * 100):.0f}%)'

    plt.title(title, fontsize=4)

fig.suptitle('ShuffleNet - predictions')
# Out:
# Text(0.5, 0.98, 'ShuffleNet - predictions')

# %%
"""
ShuffleNet
Mine(batch_size = 32):
After 20 Epoch: 67.0%
After 40 Epoch: 78.8%
After 59 Epoch: 79.4%
structure:
----------------------------------------------------------------
        Layer (type)               Output Shape         Param #
================================================================
            Conv2d-1         [-1, 24, 112, 112]             648
       BatchNorm2d-2         [-1, 24, 112, 112]              48
              ReLU-3         [-1, 24, 112, 112]               0
       BasicConv2d-4         [-1, 24, 112, 112]               0
         MaxPool2d-5           [-1, 24, 56, 56]               0
            Conv2d-6            [-1, 6, 56, 56]              78
       BatchNorm2d-7            [-1, 6, 56, 56]              12
              ReLU-8            [-1, 6, 56, 56]               0
       BasicConv2d-9            [-1, 6, 56, 56]               0
     ShuffleBlock-10            [-1, 6, 56, 56]               0
           Conv2d-11            [-1, 6, 28, 28]              60
      BatchNorm2d-12            [-1, 6, 28, 28]              12
      BasicConv2d-13            [-1, 6, 28, 28]               0
           Conv2d-14          [-1, 176, 28, 28]             704
      BatchNorm2d-15          [-1, 176, 28, 28]             352
      BasicConv2d-16          [-1, 176, 28, 28]               0
      ShuffleUnit-17          [-1, 200, 28, 28]               0
           Conv2d-18           [-1, 50, 28, 28]           5,050
      BatchNorm2d-19           [-1, 50, 28, 28]             100
             ReLU-20           [-1, 50, 28, 28]               0
      BasicConv2d-21           [-1, 50, 28, 28]               0
     ShuffleBlock-22           [-1, 50, 28, 28]               0
           Conv2d-23           [-1, 50, 28, 28]             500
      BatchNorm2d-24           [-1, 50, 28, 28]             100
      BasicConv2d-25           [-1, 50, 28, 28]               0
           Conv2d-26          [-1, 200, 28, 28]           5,200
      BatchNorm2d-27          [-1, 200, 28, 28]             400
      BasicConv2d-28          [-1, 200, 28, 28]               0
      ShuffleUnit-29          [-1, 200, 28, 28]               0
           Conv2d-30           [-1, 50, 28, 28]           5,050
      BatchNorm2d-31           [-1, 50, 28, 28]             100
             ReLU-32           [-1, 50, 28, 28]               0
      BasicConv2d-33           [-1, 50, 28, 28]               0
     ShuffleBlock-34           [-1, 50, 28, 28]               0
           Conv2d-35           [-1, 50, 28, 28]             500
      BatchNorm2d-36           [-1, 50, 28, 28]             100
      BasicConv2d-37           [-1, 50, 28, 28]               0
           Conv2d-38          [-1, 200, 28, 28]           5,200
      BatchNorm2d-39          [-1, 200, 28, 28]             400
      BasicConv2d-40          [-1, 200, 28, 28]               0
      ShuffleUnit-41          [-1, 200, 28, 28]               0
           Conv2d-42           [-1, 50, 28, 28]           5,050
      BatchNorm2d-43           [-1, 50, 28, 28]             100
             ReLU-44           [-1, 50, 28, 28]               0
      BasicConv2d-45           [-1, 50, 28, 28]               0
     ShuffleBlock-46           [-1, 50, 28, 28]               0
           Conv2d-47           [-1, 50, 14, 14]             500
      BatchNorm2d-48           [-1, 50, 14, 14]             100
      BasicConv2d-49           [-1, 50, 14, 14]               0
           Conv2d-50          [-1, 200, 14, 14]           5,200
      BatchNorm2d-51          [-1, 200, 14, 14]             400
      BasicConv2d-52          [-1, 200, 14, 14]               0
      ShuffleUnit-53          [-1, 400, 14, 14]               0
           Conv2d-54          [-1, 100, 14, 14]          20,100
      BatchNorm2d-55          [-1, 100, 14, 14]             200
             ReLU-56          [-1, 100, 14, 14]               0
      BasicConv2d-57          [-1, 100, 14, 14]               0
     ShuffleBlock-58          [-1, 100, 14, 14]               0
           Conv2d-59          [-1, 100, 14, 14]           1,000
      BatchNorm2d-60          [-1, 100, 14, 14]             200
      BasicConv2d-61          [-1, 100, 14, 14]               0
           Conv2d-62          [-1, 400, 14, 14]          20,400
      BatchNorm2d-63          [-1, 400, 14, 14]             800
      BasicConv2d-64          [-1, 400, 14, 14]               0
      ShuffleUnit-65          [-1, 400, 14, 14]               0
           Conv2d-66          [-1, 100, 14, 14]          20,100
      BatchNorm2d-67          [-1, 100, 14, 14]             200
             ReLU-68          [-1, 100, 14, 14]               0
      BasicConv2d-69          [-1, 100, 14, 14]               0
     ShuffleBlock-70          [-1, 100, 14, 14]               0
           Conv2d-71          [-1, 100, 14, 14]           1,000
      BatchNorm2d-72          [-1, 100, 14, 14]             200
      BasicConv2d-73          [-1, 100, 14, 14]               0
           Conv2d-74          [-1, 400, 14, 14]          20,400
      BatchNorm2d-75          [-1, 400, 14, 14]             800
      BasicConv2d-76          [-1, 400, 14, 14]               0
      ShuffleUnit-77          [-1, 400, 14, 14]               0
           Conv2d-78          [-1, 100, 14, 14]          20,100
      BatchNorm2d-79          [-1, 100, 14, 14]             200
             ReLU-80          [-1, 100, 14, 14]               0
      BasicConv2d-81          [-1, 100, 14, 14]               0
     ShuffleBlock-82          [-1, 100, 14, 14]               0
           Conv2d-83          [-1, 100, 14, 14]           1,000
      BatchNorm2d-84          [-1, 100, 14, 14]             200
      BasicConv2d-85          [-1, 100, 14, 14]               0
           Conv2d-86          [-1, 400, 14, 14]          20,400
      BatchNorm2d-87          [-1, 400, 14, 14]             800
      BasicConv2d-88          [-1, 400, 14, 14]               0
      ShuffleUnit-89          [-1, 400, 14, 14]               0
           Conv2d-90          [-1, 100, 14, 14]          20,100
      BatchNorm2d-91          [-1, 100, 14, 14]             200
             ReLU-92          [-1, 100, 14, 14]               0
      BasicConv2d-93          [-1, 100, 14, 14]               0
     ShuffleBlock-94          [-1, 100, 14, 14]               0
           Conv2d-95          [-1, 100, 14, 14]           1,000
      BatchNorm2d-96          [-1, 100, 14, 14]             200
      BasicConv2d-97          [-1, 100, 14, 14]               0
           Conv2d-98          [-1, 400, 14, 14]          20,400
      BatchNorm2d-99          [-1, 400, 14, 14]             800
     BasicConv2d-100          [-1, 400, 14, 14]               0
     ShuffleUnit-101          [-1, 400, 14, 14]               0
          Conv2d-102          [-1, 100, 14, 14]          20,100
     BatchNorm2d-103          [-1, 100, 14, 14]             200
            ReLU-104          [-1, 100, 14, 14]               0
     BasicConv2d-105          [-1, 100, 14, 14]               0
    ShuffleBlock-106          [-1, 100, 14, 14]               0
          Conv2d-107          [-1, 100, 14, 14]           1,000
     BatchNorm2d-108          [-1, 100, 14, 14]             200
     BasicConv2d-109          [-1, 100, 14, 14]               0
          Conv2d-110          [-1, 400, 14, 14]          20,400
     BatchNorm2d-111          [-1, 400, 14, 14]             800
     BasicConv2d-112          [-1, 400, 14, 14]               0
     ShuffleUnit-113          [-1, 400, 14, 14]               0
          Conv2d-114          [-1, 100, 14, 14]          20,100
     BatchNorm2d-115          [-1, 100, 14, 14]             200
            ReLU-116          [-1, 100, 14, 14]               0
     BasicConv2d-117          [-1, 100, 14, 14]               0
    ShuffleBlock-118          [-1, 100, 14, 14]               0
          Conv2d-119          [-1, 100, 14, 14]           1,000
     BatchNorm2d-120          [-1, 100, 14, 14]             200
     BasicConv2d-121          [-1, 100, 14, 14]               0
          Conv2d-122          [-1, 400, 14, 14]          20,400
     BatchNorm2d-123          [-1, 400, 14, 14]             800
     BasicConv2d-124          [-1, 400, 14, 14]               0
     ShuffleUnit-125          [-1, 400, 14, 14]               0
          Conv2d-126          [-1, 100, 14, 14]          20,100
     BatchNorm2d-127          [-1, 100, 14, 14]             200
            ReLU-128          [-1, 100, 14, 14]               0
     BasicConv2d-129          [-1, 100, 14, 14]               0
    ShuffleBlock-130          [-1, 100, 14, 14]               0
          Conv2d-131            [-1, 100, 7, 7]           1,000
     BatchNorm2d-132            [-1, 100, 7, 7]             200
     BasicConv2d-133            [-1, 100, 7, 7]               0
          Conv2d-134            [-1, 400, 7, 7]          20,400
     BatchNorm2d-135            [-1, 400, 7, 7]             800
     BasicConv2d-136            [-1, 400, 7, 7]               0
     ShuffleUnit-137            [-1, 800, 7, 7]               0
          Conv2d-138            [-1, 200, 7, 7]          80,200
     BatchNorm2d-139            [-1, 200, 7, 7]             400
            ReLU-140            [-1, 200, 7, 7]               0
     BasicConv2d-141            [-1, 200, 7, 7]               0
    ShuffleBlock-142            [-1, 200, 7, 7]               0
          Conv2d-143            [-1, 200, 7, 7]           2,000
     BatchNorm2d-144            [-1, 200, 7, 7]             400
     BasicConv2d-145            [-1, 200, 7, 7]               0
          Conv2d-146            [-1, 800, 7, 7]          80,800
     BatchNorm2d-147            [-1, 800, 7, 7]           1,600
     BasicConv2d-148            [-1, 800, 7, 7]               0
     ShuffleUnit-149            [-1, 800, 7, 7]               0
          Conv2d-150            [-1, 200, 7, 7]          80,200
     BatchNorm2d-151            [-1, 200, 7, 7]             400
            ReLU-152            [-1, 200, 7, 7]               0
     BasicConv2d-153            [-1, 200, 7, 7]               0
    ShuffleBlock-154            [-1, 200, 7, 7]               0
          Conv2d-155            [-1, 200, 7, 7]           2,000
     BatchNorm2d-156            [-1, 200, 7, 7]             400
     BasicConv2d-157            [-1, 200, 7, 7]               0
          Conv2d-158            [-1, 800, 7, 7]          80,800
     BatchNorm2d-159            [-1, 800, 7, 7]           1,600
     BasicConv2d-160            [-1, 800, 7, 7]               0
     ShuffleUnit-161            [-1, 800, 7, 7]               0
       AvgPool2d-162            [-1, 800, 1, 1]               0
          Linear-163                   [-1, 10]           8,010
================================================================
Total params: 673,674
Trainable params: 673,674
Non-trainable params: 0
----------------------------------------------------------------
Input size (MB): 0.57
Forward/backward pass size (MB): 59.25
Params size (MB): 2.57
Estimated Total Size (MB): 62.39
----------------------------------------------------------------
parameters_count: 673674
"""
